# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
# Function to calculate return MAC from each layer

def mac_each_layer(l):
    o_shape, i_shape, ks, filters = ['', '', ''], ['', '', ''], [0, 0], [0, 0]
    macc = 0
    if ('Dense' in str(l)):
        print(l.input_shape)
        print(l.output_shape)

        i_shape = l.input.shape[1:4].as_list()[0]
        o_shape = l.output.shape[1:4].as_list()
        print(i_shape)
        print(o_shape)
        macc = (o_shape[0] * i_shape)

    if ('Conv2D ' in str(l) and 'DepthwiseConv2D' not in str(l) and 'SeparableConv2D' not in str(l)):
        strides = l.strides
        ks = l.kernel_size
        filters = l.filters
        i_shape = l.input.get_shape()[1:4].as_list()
        o_shape = l.output.get_shape()[1:4].as_list()

        if (filters == None):
            filters = i_shape[2]
        macc = (filters * o_shape[0] * o_shape[1]) * (i_shape[2] * ks[0] * ks[1] )
    if ('Conv2D ' in str(l) and 'DepthwiseConv2D' in str(l) and 'SeparableConv2D' not in str(l)):
        strides = l.strides
        ks = l.kernel_size
        filters = l.filters
        i_shape = l.input.get_shape()[1:4].as_list()
        o_shape = l.output.get_shape()[1:4].as_list()

        if (filters == None):
            filters = i_shape[2]

        macc = (o_shape[0] *o_shape[1]) * (i_shape[2] * ks[0] * ks[1] )

    return macc

# Function to pass layers to the calculating function and to get the macc of each layer

def MAC_summary(model):
  print('%25s | %6s' % ('Layer Name', 'MACs'))
  print('*' * 100)
  t_macc = 0
  macc_dict = {}
  prefix_name = model.name + "_"
  for l in model.layers:
    if (type(l) in [models.Sequential, keras.Model]):
      for ib_layer in l.layers:
        mac_obtained = mac_each_layer(ib_layer)
        macc_dict[prefix_name+l.name] = mac_obtained
        if ib_layer.name.endswith('conv'):
          print('%25s(%5s) | %5.4f' % (
                  prefix_name+l.name,ib_layer.name, mac_obtained ))
        t_macc += mac_obtained

    else:
      mac_obtained = mac_each_layer(l)
      macc_dict[prefix_name+l.name] = mac_obtained
      if l.name.endswith('conv'):
        print('%25s | %5.4f' % (
                  prefix_name+l.name, mac_obtained ))

    t_macc += mac_obtained
  print('\nTotal MACs operations in the complete model: %10.8f\n' % (t_macc))
  return macc_dict

# %%
# Obtains the output in bits, the memory requirements of each layer

def keras_model_output(model):
    print('%25s | %6s' % ('Layer Name', 'Output bits'))
    print('*' * 100)
    output_dict = {}
    default_dtype = tf.keras.backend.floatx()
    prefix_name = model.name + "_"
    for layer in model.layers:
        if isinstance(layer, (tf.keras.Model,models.Sequential)):
            keras_model_output(layer)
        else:
            no_of_neurons = tf.as_dtype(layer.dtype or default_dtype).size # dtype is float 32 and the size here is 4 bytes(32 bits)
            out_shape = layer.output_shape
            if isinstance(out_shape, list):
                for s in out_shape[0]:
                    if s is None:
                        continue
                    no_of_neurons *= s # Output obtained here is in 4 Bytes
            else:
                for s in out_shape:
                    if s is None:
                        continue
                    no_of_neurons *= s # Output obtained here is in 4 Bytes
            no_of_neurons *= 8 # Output obtained in bits
        output_dict[prefix_name + layer.name] = no_of_neurons
        print('%25s | %5.4f' % (
                  prefix_name+layer.name, no_of_neurons ))


    return output_dict

# %%
# EFFECTIVE DATA COMMUNICATION PROBABILITY

# Function to print the effective data communicated
def data_summary(model,x_test,y_test):

  # Creating dictionary for storing the percent of data communicated eliminating the sparse data
  effective_probability = {}

  # Function to add communicated data to the metrics
  def add_metrics(m2):
    "Annotates recursiverly a (non-compiled) model with metrics that calculate probability of non-zero activity"
    prefix_name = m2.name + "_"

    for ll in m2.layers:
        if is_hier_layer(ll):
            add_metrics(ll)
        else:
            my_metric = tf.reduce_sum( tf.math.count_nonzero(ll.output, dtype=tf.int32) / tf.size( ll.output)  )
            name=prefix_name + ll.name
            m2.add_metric(my_metric, name=name)

    return

  # Function to check if a layer is model or not
  def is_hier_layer(layer):
      "Finds if layer is actually a model instead of a single layer"
      return type(layer) in [models.Sequential, keras.Model]

  # Clone the model. Note that it is not compiled!
  m2 = keras.models.clone_model(model)
  add_metrics(m2)

  # Compiling the cloned model and take the inference
  m2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  # m2.fit(x_test, y_test, epochs=5)
  m2.evaluate(x_test[0:100], y_test[0:100])

  print('%25s | %20s' % ('Metrics and Layer Name', 'Effective data communicated'))
  print("*" * 150)
  for l in m2.metrics:
    # print('%40s | %5.4f' % (l.name, l.result().numpy()))
    if l.name!="loss" and l.name!="accuracy" :
      effective_probability[l.name] = l.result().numpy()
      print('%25s | %5.4f' % (
                  l.name, effective_probability[l.name] ))

  return effective_probability

# %%
# ImageNet classification dataset for Resnet18 and ResNet50
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data() #Size is (, 32,32,3)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
# Calculations for Resnet50 CNN model
from tensorflow.keras.applications.resnet50 import ResNet50
model_Resnet50 = ResNet50(include_top=False,
                        weights='imagenet',
                        input_shape=(32, 32, 3),
                        pooling=None)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
MAC_summary(model_Resnet50)
# Out:
#                Layer Name |   MACs
# ****************************************************************************************************
#       resnet50_conv1_conv | 2408448.0000
# resnet50_conv2_block1_1_conv | 262144.0000
# resnet50_conv2_block1_2_conv | 2359296.0000
# resnet50_conv2_block1_0_conv | 1048576.0000
# resnet50_conv2_block1_3_conv | 1048576.0000
# resnet50_conv2_block2_1_conv | 1048576.0000
# resnet50_conv2_block2_2_conv | 2359296.0000
# resnet50_conv2_block2_3_conv | 1048576.0000
# resnet50_conv2_block3_1_conv | 1048576.0000
# resnet50_conv2_block3_2_conv | 2359296.0000
# resnet50_conv2_block3_3_conv | 1048576.0000
# resnet50_conv3_block1_1_conv | 524288.0000
# resnet50_conv3_block1_2_conv | 2359296.0000
# resnet50_conv3_block1_0_conv | 2097152.0000
# resnet50_conv3_block1_3_conv | 1048576.0000
# resnet50_conv3_block2_1_conv | 1048576.0000
# resnet50_conv3_block2_2_conv | 2359296.0000
# resnet50_conv3_block2_3_conv | 1048576.0000
# resnet50_conv3_block3_1_conv | 1048576.0000
# resnet50_conv3_block3_2_conv | 2359296.0000
# resnet50_conv3_block3_3_conv | 1048576.0000
# resnet50_conv3_block4_1_conv | 1048576.0000
# resnet50_conv3_block4_2_conv | 2359296.0000
# resnet50_conv3_block4_3_conv | 1048576.0000
# resnet50_conv4_block1_1_conv | 524288.0000
# resnet50_conv4_block1_2_conv | 2359296.0000
# resnet50_conv4_block1_0_conv | 2097152.0000
# resnet50_conv4_block1_3_conv | 1048576.0000
# resnet50_conv4_block2_1_conv | 1048576.0000
# resnet50_conv4_block2_2_conv | 2359296.0000
# resnet50_conv4_block2_3_conv | 1048576.0000
# resnet50_conv4_block3_1_conv | 1048576.0000
# resnet50_conv4_block3_2_conv | 2359296.0000
# resnet50_conv4_block3_3_conv | 1048576.0000
# resnet50_conv4_block4_1_conv | 1048576.0000
# resnet50_conv4_block4_2_conv | 2359296.0000
# resnet50_conv4_block4_3_conv | 1048576.0000
# resnet50_conv4_block5_1_conv | 1048576.0000
# resnet50_conv4_block5_2_conv | 2359296.0000
# resnet50_conv4_block5_3_conv | 1048576.0000
# resnet50_conv4_block6_1_conv | 1048576.0000
# resnet50_conv4_block6_2_conv | 2359296.0000
# resnet50_conv4_block6_3_conv | 1048576.0000
# resnet50_conv5_block1_1_conv | 524288.0000
# resnet50_conv5_block1_2_conv | 2359296.0000
# resnet50_conv5_block1_0_conv | 2097152.0000
# resnet50_conv5_block1_3_conv | 1048576.0000
# resnet50_conv5_block2_1_conv | 1048576.0000
# resnet50_conv5_block2_2_conv | 2359296.0000
# resnet50_conv5_block2_3_conv | 1048576.0000
# resnet50_conv5_block3_1_conv | 1048576.0000
# resnet50_conv5_block3_2_conv | 2359296.0000
# resnet50_conv5_block3_3_conv | 1048576.0000
#
# Total MACs operations in the complete model: 78692352.00000000
# {'resnet50_input_1': 0,
#  'resnet50_conv1_pad': 0,
#  'resnet50_conv1_conv': 2408448,
#  'resnet50_conv1_bn': 0,
#  'resnet50_conv1_relu': 0,
#  'resnet50_pool1_pad': 0,
#  'resnet50_pool1_pool': 0,
#  'resnet50_conv2_block1_1_conv': 262144,
#  'resnet50_conv2_block1_1_bn': 0,
#  'resnet50_conv2_block1_1_relu': 0,
#  'resnet50_conv2_block1_2_conv': 2359296,
#  'resnet50_conv2_block1_2_bn': 0,
#  'resnet50_conv2_block1_2_relu': 0,
#  'resnet50_conv2_block1_0_conv': 1048576,
#  'resnet50_conv2_block1_3_conv': 1048576,
#  'resnet50_conv2_block1_0_bn': 0,
#  'resnet50_conv2_block1_3_bn': 0,
#  'resnet50_conv2_block1_add': 0,
#  'resnet50_conv2_block1_out': 0,
#  'resnet50_conv2_block2_1_conv': 1048576,
#  'resnet50_conv2_block2_1_bn': 0,
#  'resnet50_conv2_block2_1_relu': 0,
#  'resnet50_conv2_block2_2_conv': 2359296,
#  'resnet50_conv2_block2_2_bn': 0,
#  'resnet50_conv2_block2_2_relu': 0,
#  'resnet50_conv2_block2_3_conv': 1048576,
#  'resnet50_conv2_block2_3_bn': 0,
#  'resnet50_conv2_block2_add': 0,
#  'resnet50_conv2_block2_out': 0,
#  'resnet50_conv2_block3_1_conv': 1048576,
#  'resnet50_conv2_block3_1_bn': 0,
#  'resnet50_conv2_block3_1_relu': 0,
#  'resnet50_conv2_block3_2_conv': 2359296,
#  'resnet50_conv2_block3_2_bn': 0,
#  'resnet50_conv2_block3_2_relu': 0,
#  'resnet50_conv2_block3_3_conv': 1048576,
#  'resnet50_conv2_block3_3_bn': 0,
#  'resnet50_conv2_block3_add': 0,
#  'resnet50_conv2_block3_out': 0,
#  'resnet50_conv3_block1_1_conv': 524288,
#  'resnet50_conv3_block1_1_bn': 0,
#  'resnet50_conv3_block1_1_relu': 0,
#  'resnet50_conv3_block1_2_conv': 2359296,
#  'resnet50_conv3_block1_2_bn': 0,
#  'resnet50_conv3_block1_2_relu': 0,
#  'resnet50_conv3_block1_0_conv': 2097152,
#  'resnet50_conv3_block1_3_conv': 1048576,
#  'resnet50_conv3_block1_0_bn': 0,
#  'resnet50_conv3_block1_3_bn': 0,
#  'resnet50_conv3_block1_add': 0,
#  'resnet50_conv3_block1_out': 0,
#  'resnet50_conv3_block2_1_conv': 1048576,
#  'resnet50_conv3_block2_1_bn': 0,
#  'resnet50_conv3_block2_1_relu': 0,
#  'resnet50_conv3_block2_2_conv': 2359296,
#  'resnet50_conv3_block2_2_bn': 0,
#  'resnet50_conv3_block2_2_relu': 0,
#  'resnet50_conv3_block2_3_conv': 1048576,
#  'resnet50_conv3_block2_3_bn': 0,
#  'resnet50_conv3_block2_add': 0,
#  'resnet50_conv3_block2_out': 0,
#  'resnet50_conv3_block3_1_conv': 1048576,
#  'resnet50_conv3_block3_1_bn': 0,
#  'resnet50_conv3_block3_1_relu': 0,
#  'resnet50_conv3_block3_2_conv': 2359296,
#  'resnet50_conv3_block3_2_bn': 0,
#  'resnet50_conv3_block3_2_relu': 0,
#  'resnet50_conv3_block3_3_conv': 1048576,
#  'resnet50_conv3_block3_3_bn': 0,
#  'resnet50_conv3_block3_add': 0,
#  'resnet50_conv3_block3_out': 0,
#  'resnet50_conv3_block4_1_conv': 1048576,
#  'resnet50_conv3_block4_1_bn': 0,
#  'resnet50_conv3_block4_1_relu': 0,
#  'resnet50_conv3_block4_2_conv': 2359296,
#  'resnet50_conv3_block4_2_bn': 0,
#  'resnet50_conv3_block4_2_relu': 0,
#  'resnet50_conv3_block4_3_conv': 1048576,
#  'resnet50_conv3_block4_3_bn': 0,
#  'resnet50_conv3_block4_add': 0,
#  'resnet50_conv3_block4_out': 0,
#  'resnet50_conv4_block1_1_conv': 524288,
#  'resnet50_conv4_block1_1_bn': 0,
#  'resnet50_conv4_block1_1_relu': 0,
#  'resnet50_conv4_block1_2_conv': 2359296,
#  'resnet50_conv4_block1_2_bn': 0,
#  'resnet50_conv4_block1_2_relu': 0,
#  'resnet50_conv4_block1_0_conv': 2097152,
#  'resnet50_conv4_block1_3_conv': 1048576,
#  'resnet50_conv4_block1_0_bn': 0,
#  'resnet50_conv4_block1_3_bn': 0,
#  'resnet50_conv4_block1_add': 0,
#  'resnet50_conv4_block1_out': 0,
#  'resnet50_conv4_block2_1_conv': 1048576,
#  'resnet50_conv4_block2_1_bn': 0,
#  'resnet50_conv4_block2_1_relu': 0,
#  'resnet50_conv4_block2_2_conv': 2359296,
#  'resnet50_conv4_block2_2_bn': 0,
#  'resnet50_conv4_block2_2_relu': 0,
#  'resnet50_conv4_block2_3_conv': 1048576,
#  'resnet50_conv4_block2_3_bn': 0,
#  'resnet50_conv4_block2_add': 0,
#  'resnet50_conv4_block2_out': 0,
#  'resnet50_conv4_block3_1_conv': 1048576,
#  'resnet50_conv4_block3_1_bn': 0,
#  'resnet50_conv4_block3_1_relu': 0,
#  'resnet50_conv4_block3_2_conv': 2359296,
#  'resnet50_conv4_block3_2_bn': 0,
#  'resnet50_conv4_block3_2_relu': 0,
#  'resnet50_conv4_block3_3_conv': 1048576,
#  'resnet50_conv4_block3_3_bn': 0,
#  'resnet50_conv4_block3_add': 0,
#  'resnet50_conv4_block3_out': 0,
#  'resnet50_conv4_block4_1_conv': 1048576,
#  'resnet50_conv4_block4_1_bn': 0,
#  'resnet50_conv4_block4_1_relu': 0,
#  'resnet50_conv4_block4_2_conv': 2359296,
#  'resnet50_conv4_block4_2_bn': 0,
#  'resnet50_conv4_block4_2_relu': 0,
#  'resnet50_conv4_block4_3_conv': 1048576,
#  'resnet50_conv4_block4_3_bn': 0,
#  'resnet50_conv4_block4_add': 0,
#  'resnet50_conv4_block4_out': 0,
#  'resnet50_conv4_block5_1_conv': 1048576,
#  'resnet50_conv4_block5_1_bn': 0,
#  'resnet50_conv4_block5_1_relu': 0,
#  'resnet50_conv4_block5_2_conv': 2359296,
#  'resnet50_conv4_block5_2_bn': 0,
#  'resnet50_conv4_block5_2_relu': 0,
#  'resnet50_conv4_block5_3_conv': 1048576,
#  'resnet50_conv4_block5_3_bn': 0,
#  'resnet50_conv4_block5_add': 0,
#  'resnet50_conv4_block5_out': 0,
#  'resnet50_conv4_block6_1_conv': 1048576,
#  'resnet50_conv4_block6_1_bn': 0,
#  'resnet50_conv4_block6_1_relu': 0,
#  'resnet50_conv4_block6_2_conv': 2359296,
#  'resnet50_conv4_block6_2_bn': 0,
#  'resnet50_conv4_block6_2_relu': 0,
#  'resnet50_conv4_block6_3_conv': 1048576,
#  'resnet50_conv4_block6_3_bn': 0,
#  'resnet50_conv4_block6_add': 0,
#  'resnet50_conv4_block6_out': 0,
#  'resnet50_conv5_block1_1_conv': 524288,
#  'resnet50_conv5_block1_1_bn': 0,
#  'resnet50_conv5_block1_1_relu': 0,
#  'resnet50_conv5_block1_2_conv': 2359296,
#  'resnet50_conv5_block1_2_bn': 0,
#  'resnet50_conv5_block1_2_relu': 0,
#  'resnet50_conv5_block1_0_conv': 2097152,
#  'resnet50_conv5_block1_3_conv': 1048576,
#  'resnet50_conv5_block1_0_bn': 0,
#  'resnet50_conv5_block1_3_bn': 0,
#  'resnet50_conv5_block1_add': 0,
#  'resnet50_conv5_block1_out': 0,
#  'resnet50_conv5_block2_1_conv': 1048576,
#  'resnet50_conv5_block2_1_bn': 0,
#  'resnet50_conv5_block2_1_relu': 0,
#  'resnet50_conv5_block2_2_conv': 2359296,
#  'resnet50_conv5_block2_2_bn': 0,
#  'resnet50_conv5_block2_2_relu': 0,
#  'resnet50_conv5_block2_3_conv': 1048576,
#  'resnet50_conv5_block2_3_bn': 0,
#  'resnet50_conv5_block2_add': 0,
#  'resnet50_conv5_block2_out': 0,
#  'resnet50_conv5_block3_1_conv': 1048576,
#  'resnet50_conv5_block3_1_bn': 0,
#  'resnet50_conv5_block3_1_relu': 0,
#  'resnet50_conv5_block3_2_conv': 2359296,
#  'resnet50_conv5_block3_2_bn': 0,
#  'resnet50_conv5_block3_2_relu': 0,
#  'resnet50_conv5_block3_3_conv': 1048576,
#  'resnet50_conv5_block3_3_bn': 0,
#  'resnet50_conv5_block3_add': 0,
#  'resnet50_conv5_block3_out': 0}

# %%
keras_model_output(model_Resnet50)
# Out:
#                Layer Name | Output bits
# ****************************************************************************************************
#          resnet50_input_1 | 98304.0000
#        resnet50_conv1_pad | 138624.0000
#       resnet50_conv1_conv | 524288.0000
#         resnet50_conv1_bn | 524288.0000
#       resnet50_conv1_relu | 524288.0000
#        resnet50_pool1_pad | 663552.0000
#       resnet50_pool1_pool | 131072.0000
# resnet50_conv2_block1_1_conv | 131072.0000
# resnet50_conv2_block1_1_bn | 131072.0000
# resnet50_conv2_block1_1_relu | 131072.0000
# resnet50_conv2_block1_2_conv | 131072.0000
# resnet50_conv2_block1_2_bn | 131072.0000
# resnet50_conv2_block1_2_relu | 131072.0000
# resnet50_conv2_block1_0_conv | 524288.0000
# resnet50_conv2_block1_3_conv | 524288.0000
# resnet50_conv2_block1_0_bn | 524288.0000
# resnet50_conv2_block1_3_bn | 524288.0000
# resnet50_conv2_block1_add | 524288.0000
# resnet50_conv2_block1_out | 524288.0000
# resnet50_conv2_block2_1_conv | 131072.0000
# resnet50_conv2_block2_1_bn | 131072.0000
# resnet50_conv2_block2_1_relu | 131072.0000
# resnet50_conv2_block2_2_conv | 131072.0000
# resnet50_conv2_block2_2_bn | 131072.0000
# resnet50_conv2_block2_2_relu | 131072.0000
# resnet50_conv2_block2_3_conv | 524288.0000
# resnet50_conv2_block2_3_bn | 524288.0000
# resnet50_conv2_block2_add | 524288.0000
# resnet50_conv2_block2_out | 524288.0000
# resnet50_conv2_block3_1_conv | 131072.0000
# resnet50_conv2_block3_1_bn | 131072.0000
# resnet50_conv2_block3_1_relu | 131072.0000
# resnet50_conv2_block3_2_conv | 131072.0000
# resnet50_conv2_block3_2_bn | 131072.0000
# resnet50_conv2_block3_2_relu | 131072.0000
# resnet50_conv2_block3_3_conv | 524288.0000
# resnet50_conv2_block3_3_bn | 524288.0000
# resnet50_conv2_block3_add | 524288.0000
# resnet50_conv2_block3_out | 524288.0000
# resnet50_conv3_block1_1_conv | 65536.0000
# resnet50_conv3_block1_1_bn | 65536.0000
# resnet50_conv3_block1_1_relu | 65536.0000
# resnet50_conv3_block1_2_conv | 65536.0000
# resnet50_conv3_block1_2_bn | 65536.0000
# resnet50_conv3_block1_2_relu | 65536.0000
# resnet50_conv3_block1_0_conv | 262144.0000
# resnet50_conv3_block1_3_conv | 262144.0000
# resnet50_conv3_block1_0_bn | 262144.0000
# resnet50_conv3_block1_3_bn | 262144.0000
# resnet50_conv3_block1_add | 262144.0000
# resnet50_conv3_block1_out | 262144.0000
# resnet50_conv3_block2_1_conv | 65536.0000
# resnet50_conv3_block2_1_bn | 65536.0000
# resnet50_conv3_block2_1_relu | 65536.0000
# resnet50_conv3_block2_2_conv | 65536.0000
# resnet50_conv3_block2_2_bn | 65536.0000
# resnet50_conv3_block2_2_relu | 65536.0000
# resnet50_conv3_block2_3_conv | 262144.0000
# resnet50_conv3_block2_3_bn | 262144.0000
# resnet50_conv3_block2_add | 262144.0000
# resnet50_conv3_block2_out | 262144.0000
# resnet50_conv3_block3_1_conv | 65536.0000
# resnet50_conv3_block3_1_bn | 65536.0000
# resnet50_conv3_block3_1_relu | 65536.0000
# resnet50_conv3_block3_2_conv | 65536.0000
# resnet50_conv3_block3_2_bn | 65536.0000
# resnet50_conv3_block3_2_relu | 65536.0000
# resnet50_conv3_block3_3_conv | 262144.0000
# resnet50_conv3_block3_3_bn | 262144.0000
# resnet50_conv3_block3_add | 262144.0000
# resnet50_conv3_block3_out | 262144.0000
# resnet50_conv3_block4_1_conv | 65536.0000
# resnet50_conv3_block4_1_bn | 65536.0000
# resnet50_conv3_block4_1_relu | 65536.0000
# resnet50_conv3_block4_2_conv | 65536.0000
# resnet50_conv3_block4_2_bn | 65536.0000
# resnet50_conv3_block4_2_relu | 65536.0000
# resnet50_conv3_block4_3_conv | 262144.0000
# resnet50_conv3_block4_3_bn | 262144.0000
# resnet50_conv3_block4_add | 262144.0000
# resnet50_conv3_block4_out | 262144.0000
# resnet50_conv4_block1_1_conv | 32768.0000
# resnet50_conv4_block1_1_bn | 32768.0000
# resnet50_conv4_block1_1_relu | 32768.0000
# resnet50_conv4_block1_2_conv | 32768.0000
# resnet50_conv4_block1_2_bn | 32768.0000
# resnet50_conv4_block1_2_relu | 32768.0000
# resnet50_conv4_block1_0_conv | 131072.0000
# resnet50_conv4_block1_3_conv | 131072.0000
# resnet50_conv4_block1_0_bn | 131072.0000
# resnet50_conv4_block1_3_bn | 131072.0000
# resnet50_conv4_block1_add | 131072.0000
# resnet50_conv4_block1_out | 131072.0000
# resnet50_conv4_block2_1_conv | 32768.0000
# resnet50_conv4_block2_1_bn | 32768.0000
# resnet50_conv4_block2_1_relu | 32768.0000
# resnet50_conv4_block2_2_conv | 32768.0000
# resnet50_conv4_block2_2_bn | 32768.0000
# resnet50_conv4_block2_2_relu | 32768.0000
# resnet50_conv4_block2_3_conv | 131072.0000
# resnet50_conv4_block2_3_bn | 131072.0000
# resnet50_conv4_block2_add | 131072.0000
# resnet50_conv4_block2_out | 131072.0000
# resnet50_conv4_block3_1_conv | 32768.0000
# resnet50_conv4_block3_1_bn | 32768.0000
# resnet50_conv4_block3_1_relu | 32768.0000
# resnet50_conv4_block3_2_conv | 32768.0000
# resnet50_conv4_block3_2_bn | 32768.0000
# resnet50_conv4_block3_2_relu | 32768.0000
# resnet50_conv4_block3_3_conv | 131072.0000
# resnet50_conv4_block3_3_bn | 131072.0000
# resnet50_conv4_block3_add | 131072.0000
# resnet50_conv4_block3_out | 131072.0000
# resnet50_conv4_block4_1_conv | 32768.0000
# resnet50_conv4_block4_1_bn | 32768.0000
# resnet50_conv4_block4_1_relu | 32768.0000
# resnet50_conv4_block4_2_conv | 32768.0000
# resnet50_conv4_block4_2_bn | 32768.0000
# resnet50_conv4_block4_2_relu | 32768.0000
# resnet50_conv4_block4_3_conv | 131072.0000
# resnet50_conv4_block4_3_bn | 131072.0000
# resnet50_conv4_block4_add | 131072.0000
# resnet50_conv4_block4_out | 131072.0000
# resnet50_conv4_block5_1_conv | 32768.0000
# resnet50_conv4_block5_1_bn | 32768.0000
# resnet50_conv4_block5_1_relu | 32768.0000
# resnet50_conv4_block5_2_conv | 32768.0000
# resnet50_conv4_block5_2_bn | 32768.0000
# resnet50_conv4_block5_2_relu | 32768.0000
# resnet50_conv4_block5_3_conv | 131072.0000
# resnet50_conv4_block5_3_bn | 131072.0000
# resnet50_conv4_block5_add | 131072.0000
# resnet50_conv4_block5_out | 131072.0000
# resnet50_conv4_block6_1_conv | 32768.0000
# resnet50_conv4_block6_1_bn | 32768.0000
# resnet50_conv4_block6_1_relu | 32768.0000
# resnet50_conv4_block6_2_conv | 32768.0000
# resnet50_conv4_block6_2_bn | 32768.0000
# resnet50_conv4_block6_2_relu | 32768.0000
# resnet50_conv4_block6_3_conv | 131072.0000
# resnet50_conv4_block6_3_bn | 131072.0000
# resnet50_conv4_block6_add | 131072.0000
# resnet50_conv4_block6_out | 131072.0000
# resnet50_conv5_block1_1_conv | 16384.0000
# resnet50_conv5_block1_1_bn | 16384.0000
# resnet50_conv5_block1_1_relu | 16384.0000
# resnet50_conv5_block1_2_conv | 16384.0000
# resnet50_conv5_block1_2_bn | 16384.0000
# resnet50_conv5_block1_2_relu | 16384.0000
# resnet50_conv5_block1_0_conv | 65536.0000
# resnet50_conv5_block1_3_conv | 65536.0000
# resnet50_conv5_block1_0_bn | 65536.0000
# resnet50_conv5_block1_3_bn | 65536.0000
# resnet50_conv5_block1_add | 65536.0000
# resnet50_conv5_block1_out | 65536.0000
# resnet50_conv5_block2_1_conv | 16384.0000
# resnet50_conv5_block2_1_bn | 16384.0000
# resnet50_conv5_block2_1_relu | 16384.0000
# resnet50_conv5_block2_2_conv | 16384.0000
# resnet50_conv5_block2_2_bn | 16384.0000
# resnet50_conv5_block2_2_relu | 16384.0000
# resnet50_conv5_block2_3_conv | 65536.0000
# resnet50_conv5_block2_3_bn | 65536.0000
# resnet50_conv5_block2_add | 65536.0000
# resnet50_conv5_block2_out | 65536.0000
# resnet50_conv5_block3_1_conv | 16384.0000
# resnet50_conv5_block3_1_bn | 16384.0000
# resnet50_conv5_block3_1_relu | 16384.0000
# resnet50_conv5_block3_2_conv | 16384.0000
# resnet50_conv5_block3_2_bn | 16384.0000
# resnet50_conv5_block3_2_relu | 16384.0000
# resnet50_conv5_block3_3_conv | 65536.0000
# resnet50_conv5_block3_3_bn | 65536.0000
# resnet50_conv5_block3_add | 65536.0000
# resnet50_conv5_block3_out | 65536.0000
# {'resnet50_input_1': 98304,
#  'resnet50_conv1_pad': 138624,
#  'resnet50_conv1_conv': 524288,
#  'resnet50_conv1_bn': 524288,
#  'resnet50_conv1_relu': 524288,
#  'resnet50_pool1_pad': 663552,
#  'resnet50_pool1_pool': 131072,
#  'resnet50_conv2_block1_1_conv': 131072,
#  'resnet50_conv2_block1_1_bn': 131072,
#  'resnet50_conv2_block1_1_relu': 131072,
#  'resnet50_conv2_block1_2_conv': 131072,
#  'resnet50_conv2_block1_2_bn': 131072,
#  'resnet50_conv2_block1_2_relu': 131072,
#  'resnet50_conv2_block1_0_conv': 524288,
#  'resnet50_conv2_block1_3_conv': 524288,
#  'resnet50_conv2_block1_0_bn': 524288,
#  'resnet50_conv2_block1_3_bn': 524288,
#  'resnet50_conv2_block1_add': 524288,
#  'resnet50_conv2_block1_out': 524288,
#  'resnet50_conv2_block2_1_conv': 131072,
#  'resnet50_conv2_block2_1_bn': 131072,
#  'resnet50_conv2_block2_1_relu': 131072,
#  'resnet50_conv2_block2_2_conv': 131072,
#  'resnet50_conv2_block2_2_bn': 131072,
#  'resnet50_conv2_block2_2_relu': 131072,
#  'resnet50_conv2_block2_3_conv': 524288,
#  'resnet50_conv2_block2_3_bn': 524288,
#  'resnet50_conv2_block2_add': 524288,
#  'resnet50_conv2_block2_out': 524288,
#  'resnet50_conv2_block3_1_conv': 131072,
#  'resnet50_conv2_block3_1_bn': 131072,
#  'resnet50_conv2_block3_1_relu': 131072,
#  'resnet50_conv2_block3_2_conv': 131072,
#  'resnet50_conv2_block3_2_bn': 131072,
#  'resnet50_conv2_block3_2_relu': 131072,
#  'resnet50_conv2_block3_3_conv': 524288,
#  'resnet50_conv2_block3_3_bn': 524288,
#  'resnet50_conv2_block3_add': 524288,
#  'resnet50_conv2_block3_out': 524288,
#  'resnet50_conv3_block1_1_conv': 65536,
#  'resnet50_conv3_block1_1_bn': 65536,
#  'resnet50_conv3_block1_1_relu': 65536,
#  'resnet50_conv3_block1_2_conv': 65536,
#  'resnet50_conv3_block1_2_bn': 65536,
#  'resnet50_conv3_block1_2_relu': 65536,
#  'resnet50_conv3_block1_0_conv': 262144,
#  'resnet50_conv3_block1_3_conv': 262144,
#  'resnet50_conv3_block1_0_bn': 262144,
#  'resnet50_conv3_block1_3_bn': 262144,
#  'resnet50_conv3_block1_add': 262144,
#  'resnet50_conv3_block1_out': 262144,
#  'resnet50_conv3_block2_1_conv': 65536,
#  'resnet50_conv3_block2_1_bn': 65536,
#  'resnet50_conv3_block2_1_relu': 65536,
#  'resnet50_conv3_block2_2_conv': 65536,
#  'resnet50_conv3_block2_2_bn': 65536,
#  'resnet50_conv3_block2_2_relu': 65536,
#  'resnet50_conv3_block2_3_conv': 262144,
#  'resnet50_conv3_block2_3_bn': 262144,
#  'resnet50_conv3_block2_add': 262144,
#  'resnet50_conv3_block2_out': 262144,
#  'resnet50_conv3_block3_1_conv': 65536,
#  'resnet50_conv3_block3_1_bn': 65536,
#  'resnet50_conv3_block3_1_relu': 65536,
#  'resnet50_conv3_block3_2_conv': 65536,
#  'resnet50_conv3_block3_2_bn': 65536,
#  'resnet50_conv3_block3_2_relu': 65536,
#  'resnet50_conv3_block3_3_conv': 262144,
#  'resnet50_conv3_block3_3_bn': 262144,
#  'resnet50_conv3_block3_add': 262144,
#  'resnet50_conv3_block3_out': 262144,
#  'resnet50_conv3_block4_1_conv': 65536,
#  'resnet50_conv3_block4_1_bn': 65536,
#  'resnet50_conv3_block4_1_relu': 65536,
#  'resnet50_conv3_block4_2_conv': 65536,
#  'resnet50_conv3_block4_2_bn': 65536,
#  'resnet50_conv3_block4_2_relu': 65536,
#  'resnet50_conv3_block4_3_conv': 262144,
#  'resnet50_conv3_block4_3_bn': 262144,
#  'resnet50_conv3_block4_add': 262144,
#  'resnet50_conv3_block4_out': 262144,
#  'resnet50_conv4_block1_1_conv': 32768,
#  'resnet50_conv4_block1_1_bn': 32768,
#  'resnet50_conv4_block1_1_relu': 32768,
#  'resnet50_conv4_block1_2_conv': 32768,
#  'resnet50_conv4_block1_2_bn': 32768,
#  'resnet50_conv4_block1_2_relu': 32768,
#  'resnet50_conv4_block1_0_conv': 131072,
#  'resnet50_conv4_block1_3_conv': 131072,
#  'resnet50_conv4_block1_0_bn': 131072,
#  'resnet50_conv4_block1_3_bn': 131072,
#  'resnet50_conv4_block1_add': 131072,
#  'resnet50_conv4_block1_out': 131072,
#  'resnet50_conv4_block2_1_conv': 32768,
#  'resnet50_conv4_block2_1_bn': 32768,
#  'resnet50_conv4_block2_1_relu': 32768,
#  'resnet50_conv4_block2_2_conv': 32768,
#  'resnet50_conv4_block2_2_bn': 32768,
#  'resnet50_conv4_block2_2_relu': 32768,
#  'resnet50_conv4_block2_3_conv': 131072,
#  'resnet50_conv4_block2_3_bn': 131072,
#  'resnet50_conv4_block2_add': 131072,
#  'resnet50_conv4_block2_out': 131072,
#  'resnet50_conv4_block3_1_conv': 32768,
#  'resnet50_conv4_block3_1_bn': 32768,
#  'resnet50_conv4_block3_1_relu': 32768,
#  'resnet50_conv4_block3_2_conv': 32768,
#  'resnet50_conv4_block3_2_bn': 32768,
#  'resnet50_conv4_block3_2_relu': 32768,
#  'resnet50_conv4_block3_3_conv': 131072,
#  'resnet50_conv4_block3_3_bn': 131072,
#  'resnet50_conv4_block3_add': 131072,
#  'resnet50_conv4_block3_out': 131072,
#  'resnet50_conv4_block4_1_conv': 32768,
#  'resnet50_conv4_block4_1_bn': 32768,
#  'resnet50_conv4_block4_1_relu': 32768,
#  'resnet50_conv4_block4_2_conv': 32768,
#  'resnet50_conv4_block4_2_bn': 32768,
#  'resnet50_conv4_block4_2_relu': 32768,
#  'resnet50_conv4_block4_3_conv': 131072,
#  'resnet50_conv4_block4_3_bn': 131072,
#  'resnet50_conv4_block4_add': 131072,
#  'resnet50_conv4_block4_out': 131072,
#  'resnet50_conv4_block5_1_conv': 32768,
#  'resnet50_conv4_block5_1_bn': 32768,
#  'resnet50_conv4_block5_1_relu': 32768,
#  'resnet50_conv4_block5_2_conv': 32768,
#  'resnet50_conv4_block5_2_bn': 32768,
#  'resnet50_conv4_block5_2_relu': 32768,
#  'resnet50_conv4_block5_3_conv': 131072,
#  'resnet50_conv4_block5_3_bn': 131072,
#  'resnet50_conv4_block5_add': 131072,
#  'resnet50_conv4_block5_out': 131072,
#  'resnet50_conv4_block6_1_conv': 32768,
#  'resnet50_conv4_block6_1_bn': 32768,
#  'resnet50_conv4_block6_1_relu': 32768,
#  'resnet50_conv4_block6_2_conv': 32768,
#  'resnet50_conv4_block6_2_bn': 32768,
#  'resnet50_conv4_block6_2_relu': 32768,
#  'resnet50_conv4_block6_3_conv': 131072,
#  'resnet50_conv4_block6_3_bn': 131072,
#  'resnet50_conv4_block6_add': 131072,
#  'resnet50_conv4_block6_out': 131072,
#  'resnet50_conv5_block1_1_conv': 16384,
#  'resnet50_conv5_block1_1_bn': 16384,
#  'resnet50_conv5_block1_1_relu': 16384,
#  'resnet50_conv5_block1_2_conv': 16384,
#  'resnet50_conv5_block1_2_bn': 16384,
#  'resnet50_conv5_block1_2_relu': 16384,
#  'resnet50_conv5_block1_0_conv': 65536,
#  'resnet50_conv5_block1_3_conv': 65536,
#  'resnet50_conv5_block1_0_bn': 65536,
#  'resnet50_conv5_block1_3_bn': 65536,
#  'resnet50_conv5_block1_add': 65536,
#  'resnet50_conv5_block1_out': 65536,
#  'resnet50_conv5_block2_1_conv': 16384,
#  'resnet50_conv5_block2_1_bn': 16384,
#  'resnet50_conv5_block2_1_relu': 16384,
#  'resnet50_conv5_block2_2_conv': 16384,
#  'resnet50_conv5_block2_2_bn': 16384,
#  'resnet50_conv5_block2_2_relu': 16384,
#  'resnet50_conv5_block2_3_conv': 65536,
#  'resnet50_conv5_block2_3_bn': 65536,
#  'resnet50_conv5_block2_add': 65536,
#  'resnet50_conv5_block2_out': 65536,
#  'resnet50_conv5_block3_1_conv': 16384,
#  'resnet50_conv5_block3_1_bn': 16384,
#  'resnet50_conv5_block3_1_relu': 16384,
#  'resnet50_conv5_block3_2_conv': 16384,
#  'resnet50_conv5_block3_2_bn': 16384,
#  'resnet50_conv5_block3_2_relu': 16384,
#  'resnet50_conv5_block3_3_conv': 65536,
#  'resnet50_conv5_block3_3_bn': 65536,
#  'resnet50_conv5_block3_add': 65536,
#  'resnet50_conv5_block3_out': 65536}

# %%
data_summary(model_Resnet50,x_train, y_train)
# Out:
# 4/4 [==============================] - 16s 194ms/step - loss: 10.3148 - accuracy: 0.0000e+00 - resnet50_input_1: 0.9591 - resnet50_conv1_pad: 0.6801 - resnet50_conv1_conv: 0.9900 - resnet50_conv1_bn: 0.9900 - resnet50_conv1_relu: 0.5291 - resnet50_pool1_pad: 0.4180 - resnet50_pool1_pool: 0.7122 - resnet50_conv2_block1_1_conv: 0.9980 - resnet50_conv2_block1_1_bn: 0.9980 - resnet50_conv2_block1_1_relu: 0.5116 - resnet50_conv2_block1_2_conv: 1.0000 - resnet50_conv2_block1_2_bn: 1.0000 - resnet50_conv2_block1_2_relu: 0.4683 - resnet50_conv2_block1_0_conv: 0.9980 - resnet50_conv2_block1_3_conv: 1.0000 - resnet50_conv2_block1_0_bn: 0.9980 - resnet50_conv2_block1_3_bn: 1.0000 - resnet50_conv2_block1_add: 1.0000 - resnet50_conv2_block1_out: 0.4623 - resnet50_conv2_block2_1_conv: 1.0000 - resnet50_conv2_block2_1_bn: 1.0000 - resnet50_conv2_block2_1_relu: 0.4412 - resnet50_conv2_block2_2_conv: 1.0000 - resnet50_conv2_block2_2_bn: 1.0000 - resnet50_conv2_block2_2_relu: 0.5050 - resnet50_conv2_block2_3_conv: 1.0000 - resnet50_conv2_block2_3_bn: 1.0000 - resnet50_conv2_block2_add: 1.0000 - resnet50_conv2_block2_out: 0.7105 - resnet50_conv2_block3_1_conv: 1.0000 - resnet50_conv2_block3_1_bn: 1.0000 - resnet50_conv2_block3_1_relu: 0.4788 - resnet50_conv2_block3_2_conv: 1.0000 - resnet50_conv2_block3_2_bn: 1.0000 - resnet50_conv2_block3_2_relu: 0.5350 - resnet50_conv2_block3_3_conv: 1.0000 - resnet50_conv2_block3_3_bn: 1.0000 - resnet50_conv2_block3_add: 1.0000 - resnet50_conv2_block3_out: 0.7408 - resnet50_conv3_block1_1_conv: 1.0000 - resnet50_conv3_block1_1_bn: 1.0000 - resnet50_conv3_block1_1_relu: 0.4786 - resnet50_conv3_block1_2_conv: 1.0000 - resnet50_conv3_block1_2_bn: 1.0000 - resnet50_conv3_block1_2_relu: 0.4809 - resnet50_conv3_block1_0_conv: 1.0000 - resnet50_conv3_block1_3_conv: 1.0000 - resnet50_conv3_block1_0_bn: 1.0000 - resnet50_conv3_block1_3_bn: 1.0000 - resnet50_conv3_block1_add: 1.0000 - resnet50_conv3_block1_out: 0.4854 - resnet50_conv3_block2_1_conv: 1.0000 - resnet50_conv3_block2_1_bn: 1.0000 - resnet50_conv3_block2_1_relu: 0.4898 - resnet50_conv3_block2_2_conv: 1.0000 - resnet50_conv3_block2_2_bn: 1.0000 - resnet50_conv3_block2_2_relu: 0.5397 - resnet50_conv3_block2_3_conv: 1.0000 - resnet50_conv3_block2_3_bn: 1.0000 - resnet50_conv3_block2_add: 1.0000 - resnet50_conv3_block2_out: 0.7307 - resnet50_conv3_block3_1_conv: 1.0000 - resnet50_conv3_block3_1_bn: 1.0000 - resnet50_conv3_block3_1_relu: 0.4518 - resnet50_conv3_block3_2_conv: 1.0000 - resnet50_conv3_block3_2_bn: 1.0000 - resnet50_conv3_block3_2_relu: 0.5458 - resnet50_conv3_block3_3_conv: 1.0000 - resnet50_conv3_block3_3_bn: 1.0000 - resnet50_conv3_block3_add: 1.0000 - resnet50_conv3_block3_out: 0.7694 - resnet50_conv3_block4_1_conv: 1.0000 - resnet50_conv3_block4_1_bn: 1.0000 - resnet50_conv3_block4_1_relu: 0.4981 - resnet50_conv3_block4_2_conv: 1.0000 - resnet50_conv3_block4_2_bn: 1.0000 - resnet50_conv3_block4_2_relu: 0.5252 - resnet50_conv3_block4_3_conv: 1.0000 - resnet50_conv3_block4_3_bn: 1.0000 - resnet50_conv3_block4_add: 1.0000 - resnet50_conv3_block4_out: 0.7920 - resnet50_conv4_block1_1_conv: 1.0000 - resnet50_conv4_block1_1_bn: 1.0000 - resnet50_conv4_block1_1_relu: 0.4679 - resnet50_conv4_block1_2_conv: 1.0000 - resnet50_conv4_block1_2_bn: 1.0000 - resnet50_conv4_block1_2_relu: 0.5405 - resnet50_conv4_block1_0_conv: 1.0000 - resnet50_conv4_block1_3_conv: 1.0000 - resnet50_conv4_block1_0_bn: 1.0000 - resnet50_conv4_block1_3_bn: 1.0000 - resnet50_conv4_block1_add: 1.0000 - resnet50_conv4_block1_out: 0.5112 - resnet50_conv4_block2_1_conv: 1.0000 - resnet50_conv4_block2_1_bn: 1.0000 - resnet50_conv4_block2_1_relu: 0.4515 - resnet50_conv4_block2_2_conv: 1.0000 - resnet50_conv4_block2_2_bn: 1.0000 - resnet50_conv4_block2_2_relu: 0.4883 - resnet50_conv4_block2_3_conv: 1.0000 - resnet50_conv4_block2_3_bn: 1.0000 - resnet50_conv4_block2_add: 1.0000 - resnet50_conv4_block2_out: 0.7184 - resnet50_conv4_block3_1_conv: 1.0000 - resnet50_conv4_block3_1_bn: 1.000 ...
#    Metrics and Layer Name | Effective data communicated
# ******************************************************************************************************************************************************
#          resnet50_input_1 | 0.9591
#        resnet50_conv1_pad | 0.6801
#       resnet50_conv1_conv | 0.9900
#         resnet50_conv1_bn | 0.9900
#       resnet50_conv1_relu | 0.5291
#        resnet50_pool1_pad | 0.4180
#       resnet50_pool1_pool | 0.7122
# resnet50_conv2_block1_1_conv | 0.9980
# resnet50_conv2_block1_1_bn | 0.9980
# resnet50_conv2_block1_1_relu | 0.5116
# resnet50_conv2_block1_2_conv | 1.0000
# resnet50_conv2_block1_2_bn | 1.0000
# resnet50_conv2_block1_2_relu | 0.4683
# resnet50_conv2_block1_0_conv | 0.9980
# resnet50_conv2_block1_3_conv | 1.0000
# resnet50_conv2_block1_0_bn | 0.9980
# resnet50_conv2_block1_3_bn | 1.0000
# resnet50_conv2_block1_add | 1.0000
# resnet50_conv2_block1_out | 0.4623
# resnet50_conv2_block2_1_conv | 1.0000
# resnet50_conv2_block2_1_bn | 1.0000
# resnet50_conv2_block2_1_relu | 0.4412
# resnet50_conv2_block2_2_conv | 1.0000
# resnet50_conv2_block2_2_bn | 1.0000
# resnet50_conv2_block2_2_relu | 0.5050
# resnet50_conv2_block2_3_conv | 1.0000
# resnet50_conv2_block2_3_bn | 1.0000
# resnet50_conv2_block2_add | 1.0000
# resnet50_conv2_block2_out | 0.7105
# resnet50_conv2_block3_1_conv | 1.0000
# resnet50_conv2_block3_1_bn | 1.0000
# resnet50_conv2_block3_1_relu | 0.4788
# resnet50_conv2_block3_2_conv | 1.0000
# resnet50_conv2_block3_2_bn | 1.0000
# resnet50_conv2_block3_2_relu | 0.5350
# resnet50_conv2_block3_3_conv | 1.0000
# resnet50_conv2_block3_3_bn | 1.0000
# resnet50_conv2_block3_add | 1.0000
# resnet50_conv2_block3_out | 0.7408
# resnet50_conv3_block1_1_conv | 1.0000
# resnet50_conv3_block1_1_bn | 1.0000
# resnet50_conv3_block1_1_relu | 0.4786
# resnet50_conv3_block1_2_conv | 1.0000
# resnet50_conv3_block1_2_bn | 1.0000
# resnet50_conv3_block1_2_relu | 0.4809
# resnet50_conv3_block1_0_conv | 1.0000
# resnet50_conv3_block1_3_conv | 1.0000
# resnet50_conv3_block1_0_bn | 1.0000
# resnet50_conv3_block1_3_bn | 1.0000
# resnet50_conv3_block1_add | 1.0000
# resnet50_conv3_block1_out | 0.4854
# resnet50_conv3_block2_1_conv | 1.0000
# resnet50_conv3_block2_1_bn | 1.0000
# resnet50_conv3_block2_1_relu | 0.4898
# resnet50_conv3_block2_2_conv | 1.0000
# resnet50_conv3_block2_2_bn | 1.0000
# resnet50_conv3_block2_2_relu | 0.5397
# resnet50_conv3_block2_3_conv | 1.0000
# resnet50_conv3_block2_3_bn | 1.0000
# resnet50_conv3_block2_add | 1.0000
# resnet50_conv3_block2_out | 0.7307
# resnet50_conv3_block3_1_conv | 1.0000
# resnet50_conv3_block3_1_bn | 1.0000
# resnet50_conv3_block3_1_relu | 0.4518
# resnet50_conv3_block3_2_conv | 1.0000
# resnet50_conv3_block3_2_bn | 1.0000
# resnet50_conv3_block3_2_relu | 0.5458
# resnet50_conv3_block3_3_conv | 1.0000
# resnet50_conv3_block3_3_bn | 1.0000
# resnet50_conv3_block3_add | 1.0000
# resnet50_conv3_block3_out | 0.7694
# resnet50_conv3_block4_1_conv | 1.0000
# resnet50_conv3_block4_1_bn | 1.0000
# resnet50_conv3_block4_1_relu | 0.4981
# resnet50_conv3_block4_2_conv | 1.0000
# resnet50_conv3_block4_2_bn | 1.0000
# resnet50_conv3_block4_2_relu | 0.5252
# resnet50_conv3_block4_3_conv | 1.0000
# resnet50_conv3_block4_3_bn | 1.0000
# resnet50_conv3_block4_add | 1.0000
# resnet50_conv3_block4_out | 0.7920
# resnet50_conv4_block1_1_conv | 1.0000
# resnet50_conv4_block1_1_bn | 1.0000
# resnet50_conv4_block1_1_relu | 0.4679
# resnet50_conv4_block1_2_conv | 1.0000
# resnet50_conv4_block1_2_bn | 1.0000
# resnet50_conv4_block1_2_relu | 0.5405
# resnet50_conv4_block1_0_conv | 1.0000
# resnet50_conv4_block1_3_conv | 1.0000
# resnet50_conv4_block1_0_bn | 1.0000
# resnet50_conv4_block1_3_bn | 1.0000
# resnet50_conv4_block1_add | 1.0000
# resnet50_conv4_block1_out | 0.5112
# resnet50_conv4_block2_1_conv | 1.0000
# resnet50_conv4_block2_1_bn | 1.0000
# resnet50_conv4_block2_1_relu | 0.4515
# resnet50_conv4_block2_2_conv | 1.0000
# resnet50_conv4_block2_2_bn | 1.0000
# resnet50_conv4_block2_2_relu | 0.4883
# resnet50_conv4_block2_3_conv | 1.0000
# resnet50_conv4_block2_3_bn | 1.0000
# resnet50_conv4_block2_add | 1.0000
# resnet50_conv4_block2_out | 0.7184
# resnet50_conv4_block3_1_conv | 1.0000
# resnet50_conv4_block3_1_bn | 1.0000
# resnet50_conv4_block3_1_relu | 0.5220
# resnet50_conv4_block3_2_conv | 1.0000
# resnet50_conv4_block3_2_bn | 1.0000
# resnet50_conv4_block3_2_relu | 0.4964
# resnet50_conv4_block3_3_conv | 1.0000
# resnet50_conv4_block3_3_bn | 1.0000
# resnet50_conv4_block3_add | 1.0000
# resnet50_conv4_block3_out | 0.7698
# resnet50_conv4_block4_1_conv | 1.0000
# resnet50_conv4_block4_1_bn | 1.0000
# resnet50_conv4_block4_1_relu | 0.5122
# resnet50_conv4_block4_2_conv | 1.0000
# resnet50_conv4_block4_2_bn | 1.0000
# resnet50_conv4_block4_2_relu | 0.5031
# resnet50_conv4_block4_3_conv | 1.0000
# resnet50_conv4_block4_3_bn | 1.0000
# resnet50_conv4_block4_add | 1.0000
# resnet50_conv4_block4_out | 0.8065
# resnet50_conv4_block5_1_conv | 1.0000
# resnet50_conv4_block5_1_bn | 1.0000
# resnet50_conv4_block5_1_relu | 0.4786
# resnet50_conv4_block5_2_conv | 1.0000
# resnet50_conv4_block5_2_bn | 1.0000
# resnet50_conv4_block5_2_relu | 0.5391
# resnet50_conv4_block5_3_conv | 1.0000
# resnet50_conv4_block5_3_bn | 1.0000
# resnet50_conv4_block5_add | 1.0000
# resnet50_conv4_block5_out | 0.8091
# resnet50_conv4_block6_1_conv | 1.0000
# resnet50_conv4_block6_1_bn | 1.0000
# resnet50_conv4_block6_1_relu | 0.5062
# resnet50_conv4_block6_2_conv | 1.0000
# resnet50_conv4_block6_2_bn | 1.0000
# resnet50_conv4_block6_2_relu | 0.4965
# resnet50_conv4_block6_3_conv | 1.0000
# resnet50_conv4_block6_3_bn | 1.0000
# resnet50_conv4_block6_add | 1.0000
# resnet50_conv4_block6_out | 0.8181
# resnet50_conv5_block1_1_conv | 1.0000
# resnet50_conv5_block1_1_bn | 1.0000
# resnet50_conv5_block1_1_relu | 0.4847
# resnet50_conv5_block1_2_conv | 1.0000
# resnet50_conv5_block1_2_bn | 1.0000
# resnet50_conv5_block1_2_relu | 0.4912
# resnet50_conv5_block1_0_conv | 1.0000
# resnet50_conv5_block1_3_conv | 1.0000
# resnet50_conv5_block1_0_bn | 1.0000
# resnet50_conv5_block1_3_bn | 1.0000
# resnet50_conv5_block1_add | 1.0000
# resnet50_conv5_block1_out | 0.4960
# resnet50_conv5_block2_1_conv | 1.0000
# resnet50_conv5_block2_1_bn | 1.0000
# resnet50_conv5_block2_1_relu | 0.5131
# resnet50_conv5_block2_2_conv | 1.0000
# resnet50_conv5_block2_2_bn | 1.0000
# resnet50_conv5_block2_2_relu | 0.4910
# resnet50_conv5_block2_3_conv | 1.0000
# resnet50_conv5_block2_3_bn | 1.0000
# resnet50_conv5_block2_add | 1.0000
# resnet50_conv5_block2_out | 0.7394
# resnet50_conv5_block3_1_conv | 1.0000
# resnet50_conv5_block3_1_bn | 1.0000
# resnet50_conv5_block3_1_relu | 0.4679
# resnet50_conv5_block3_2_conv | 1.0000
# resnet50_conv5_block3_2_bn | 1.0000
# resnet50_conv5_block3_2_relu | 0.4536
# resnet50_conv5_block3_3_conv | 1.0000
# resnet50_conv5_block3_3_bn | 1.0000
# resnet50_conv5_block3_add | 1.0000
# resnet50_conv5_block3_out | 0.7982
# {'resnet50_input_1': 0.9591013590494791,
#  'resnet50_conv1_pad': 0.6801383598799631,
#  'resnet50_conv1_conv': 0.989959716796875,
#  'resnet50_conv1_bn': 0.989959716796875,
#  'resnet50_conv1_relu': 0.5290861129760742,
#  'resnet50_pool1_pad': 0.4180433485243055,
#  'resnet50_pool1_pool': 0.7122344970703125,
#  'resnet50_conv2_block1_1_conv': 0.998046875,
#  'resnet50_conv2_block1_1_bn': 0.998046875,
#  'resnet50_conv2_block1_1_relu': 0.5116386413574219,
#  'resnet50_conv2_block1_2_conv': 1.0,
#  'resnet50_conv2_block1_2_bn': 1.0,
#  'resnet50_conv2_block1_2_relu': 0.4683265686035156,
#  'resnet50_conv2_block1_0_conv': 0.998046875,
#  'resnet50_conv2_block1_3_conv': 1.0,
#  'resnet50_conv2_block1_0_bn': 0.998046875,
#  'resnet50_conv2_block1_3_bn': 1.0,
#  'resnet50_conv2_block1_add': 1.0,
#  'resnet50_conv2_block1_out': 0.46234893798828125,
#  'resnet50_conv2_block2_1_conv': 1.0,
#  'resnet50_conv2_block2_1_bn': 1.0,
#  'resnet50_conv2_block2_1_relu': 0.44121551513671875,
#  'resnet50_conv2_block2_2_conv': 1.0,
#  'resnet50_conv2_block2_2_bn': 1.0,
#  'resnet50_conv2_block2_2_relu': 0.5050334930419922,
#  'resnet50_conv2_block2_3_conv': 1.0,
#  'resnet50_conv2_block2_3_bn': 1.0,
#  'resnet50_conv2_block2_add': 1.0,
#  'resnet50_conv2_block2_out': 0.7105131149291992,
#  'resnet50_conv2_block3_1_conv': 1.0,
#  'resnet50_conv2_block3_1_bn': 1.0,
#  'resnet50_conv2_block3_1_relu': 0.47884559631347656,
#  'resnet50_conv2_block3_2_conv': 1.0,
#  'resnet50_conv2_block3_2_bn': 1.0,
#  'resnet50_conv2_block3_2_relu': 0.5350227355957031,
#  'resnet50_conv2_block3_3_conv': 1.0,
#  'resnet50_conv2_block3_3_bn': 1.0,
#  'resnet50_conv2_block3_add': 1.0,
#  'resnet50_conv2_block3_out': 0.7407937049865723,
#  'resnet50_conv3_block1_1_conv': 1.0,
#  'resnet50_conv3_block1_1_bn': 1.0,
#  'resnet50_conv3_block1_1_relu': 0.4786224365234375,
#  'resnet50_conv3_block1_2_conv': 1.0,
#  'resnet50_conv3_block1_2_bn': 1.0,
#  'resnet50_conv3_block1_2_relu': 0.480865478515625,
#  'resnet50_conv3_block1_0_conv': 1.0,
#  'resnet50_conv3_block1_3_conv': 1.0,
#  'resnet50_conv3_block1_0_bn': 1.0,
#  'resnet50_conv3_block1_3_bn': 1.0,
#  'resnet50_conv3_block1_add': 1.0,
#  'resnet50_conv3_block1_out': 0.4853992462158203,
#  'resnet50_conv3_block2_1_conv': 1.0,
#  'resnet50_conv3_block2_1_bn': 1.0,
#  'resnet50_conv3_block2_1_relu': 0.4897575378417969,
#  'resnet50_conv3_block2_2_conv': 1.0,
#  'resnet50_conv3_block2_2_bn': 1.0,
#  'resnet50_conv3_block2_2_relu': 0.5396881103515625,
#  'resnet50_conv3_block2_3_conv': 1.0,
#  'resnet50_conv3_block2_3_bn': 1.0,
#  'resnet50_conv3_block2_add': 1.0,
#  'resnet50_conv3_block2_out': 0.7306852340698242,
#  'resnet50_conv3_block3_1_conv': 1.0,
#  'resnet50_conv3_block3_1_bn': 1.0,
#  'resnet50_conv3_block3_1_relu': 0.45178985595703125,
#  'resnet50_conv3_block3_2_conv': 1.0,
#  'resnet50_conv3_block3_2_bn': 1.0,
#  'resnet50_conv3_block3_2_relu': 0.5457763671875,
#  'resnet50_conv3_block3_3_conv': 1.0,
#  'resnet50_conv3_block3_3_bn': 1.0,
#  'resnet50_conv3_block3_add': 1.0,
#  'resnet50_conv3_block3_out': 0.7693691253662109,
#  'resnet50_conv3_block4_1_conv': 1.0,
#  'resnet50_conv3_block4_1_bn': 1.0,
#  'resnet50_conv3_block4_1_relu': 0.4981231689453125,
#  'resnet50_conv3_block4_2_conv': 1.0,
#  'resnet50_conv3_block4_2_bn': 1.0,
#  'resnet50_conv3_block4_2_relu': 0.5252189636230469,
#  'resnet50_conv3_block4_3_conv': 1.0,
#  'resnet50_conv3_block4_3_bn': 1.0,
#  'resnet50_conv3_block4_add': 1.0,
#  'resnet50_conv3_block4_out': 0.7919797897338867,
#  'resnet50_conv4_block1_1_conv': 1.0,
#  'resnet50_conv4_block1_1_bn': 1.0,
#  'resnet50_conv4_block1_1_relu': 0.46794891357421875,
#  'resnet50_conv4_block1_2_conv': 1.0,
#  'resnet50_conv4_block1_2_bn': 1.0,
#  'resnet50_conv4_block1_2_relu': 0.5404891967773438,
#  'resnet50_conv4_block1_0_conv': 1.0,
#  'resnet50_conv4_block1_3_conv': 1.0,
#  'resnet50_conv4_block1_0_bn': 1.0,
#  'resnet50_conv4_block1_3_bn': 1.0,
#  'resnet50_conv4_block1_add': 1.0,
#  'resnet50_conv4_block1_out': 0.5111522674560547,
#  'resnet50_conv4_block2_1_conv': 1.0,
#  'resnet50_conv4_block2_1_bn': 1.0,
#  'resnet50_conv4_block2_1_relu': 0.45148468017578125,
#  'resnet50_conv4_block2_2_conv': 1.0,
#  'resnet50_conv4_block2_2_bn': 1.0,
#  'resnet50_conv4_block2_2_relu': 0.48834228515625,
#  'resnet50_conv4_block2_3_conv': 1.0,
#  'resnet50_conv4_block2_3_bn': 1.0,
#  'resnet50_conv4_block2_add': 1.0,
#  'resnet50_conv4_block2_out': 0.7184486389160156,
#  'resnet50_conv4_block3_1_conv': 1.0,
#  'resnet50_conv4_block3_1_bn': 1.0,
#  'resnet50_conv4_block3_1_relu': 0.5219573974609375,
#  'resnet50_conv4_block3_2_conv': 1.0,
#  'resnet50_conv4_block3_2_bn': 1.0,
#  'resnet50_conv4_block3_2_relu': 0.49642181396484375,
#  'resnet50_conv4_block3_3_conv': 1.0,
#  'resnet50_conv4_block3_3_bn': 1.0,
#  'resnet50_conv4_block3_add': 1.0,
#  'resnet50_conv4_block3_out': 0.7698116302490234,
#  'resnet50_conv4_block4_1_conv': 1.0,
#  'resnet50_conv4_block4_1_bn': 1.0,
#  'resnet50_conv4_block4_1_relu': 0.5121688842773438,
#  'resnet50_conv4_block4_2_conv': 1.0,
#  'resnet50_conv4_block4_2_bn': 1.0,
#  'resnet50_conv4_block4_2_relu': 0.5030593872070312,
#  'resnet50_conv4_block4_3_conv': 1.0,
#  'resnet50_conv4_block4_3_bn': 1.0,
#  'resnet50_conv4_block4_add': 1.0,
#  'resnet50_conv4_block4_out': 0.8065128326416016,
#  'resnet50_conv4_block5_1_conv': 1.0,
#  'resnet50_conv4_block5_1_bn': 1.0,
#  'resnet50_conv4_block5_1_relu': 0.47858428955078125,
#  'resnet50_conv4_block5_2_conv': 1.0,
#  'resnet50_conv4_block5_2_bn': 1.0,
#  'resnet50_conv4_block5_2_relu': 0.5390777587890625,
#  'resnet50_conv4_block5_3_conv': 1.0,
#  'resnet50_conv4_block5_3_bn': 1.0,
#  'resnet50_conv4_block5_add': 1.0,
#  'resnet50_conv4_block5_out': 0.8091278076171875,
#  'resnet50_conv4_block6_1_conv': 1.0,
#  'resnet50_conv4_block6_1_bn': 1.0,
#  'resnet50_conv4_block6_1_relu': 0.5062179565429688,
#  'resnet50_conv4_block6_2_conv': 1.0,
#  'resnet50_conv4_block6_2_bn': 1.0,
#  'resnet50_conv4_block6_2_relu': 0.4965362548828125,
#  'resnet50_conv4_block6_3_conv': 1.0,
#  'resnet50_conv4_block6_3_bn': 1.0,
#  'resnet50_conv4_block6_add': 1.0,
#  'resnet50_conv4_block6_out': 0.8181324005126953,
#  'resnet50_conv5_block1_1_conv': 1.0,
#  'resnet50_conv5_block1_1_bn': 1.0,
#  'resnet50_conv5_block1_1_relu': 0.484710693359375,
#  'resnet50_conv5_block1_2_conv': 1.0,
#  'resnet50_conv5_block1_2_bn': 1.0,
#  'resnet50_conv5_block1_2_relu': 0.4912109375,
#  'resnet50_conv5_block1_0_conv': 1.0,
#  'resnet50_conv5_block1_3_conv': 1.0,
#  'resnet50_conv5_block1_0_bn': 1.0,
#  'resnet50_conv5_block1_3_bn': 1.0,
#  'resnet50_conv5_block1_add': 1.0,
#  'resnet50_conv5_block1_out': 0.4960289001464844,
#  'resnet50_conv5_block2_1_conv': 1.0,
#  'resnet50_conv5_block2_1_bn': 1.0,
#  'resnet50_conv5_block2_1_relu': 0.513092041015625,
#  'resnet50_conv5_block2_2_conv': 1.0,
#  'resnet50_conv5_block2_2_bn': 1.0,
#  'resnet50_conv5_block2_2_relu': 0.4910125732421875,
#  'resnet50_conv5_block2_3_conv': 1.0,
#  'resnet50_conv5_block2_3_bn': 1.0,
#  'resnet50_conv5_block2_add': 1.0,
#  'resnet50_conv5_block2_out': 0.7394447326660156,
#  'resnet50_conv5_block3_1_conv': 1.0,
#  'resnet50_conv5_block3_1_bn': 1.0,
#  'resnet50_conv5_block3_1_relu': 0.4678802490234375,
#  'resnet50_conv5_block3_2_conv': 1.0,
#  'resnet50_conv5_block3_2_bn': 1.0,
#  'resnet50_conv5_block3_2_relu': 0.4535980224609375,
#  'resnet50_conv5_block3_3_conv': 1.0,
#  'resnet50_conv5_block3_3_bn': 1.0,
#  'resnet50_conv5_block3_add': 1.0,
#  'resnet50_conv5_block3_out': 0.7981529235839844}
