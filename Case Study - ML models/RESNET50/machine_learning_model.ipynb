# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import losses, activations, models
from keras.layers import Dense, InputLayer,BatchNormalization, Dropout, Conv2D, Flatten, Activation

# %%
# ImageNet classification dataset for Resnet18 and ResNet50
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data() #Size is (, 32,32,3)

# %%
# Normalize the input image so that each pixel value is between 0 to 1.
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
def get_model():       
       model_Resnet50 = ResNet50(include_top=False,
                        weights='imagenet',
                        input_shape=(32, 32, 3),
                        pooling=None)
       return model_Resnet50

# %%
model_given = get_model()
model_given.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 16, 16, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 18, 18, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 8, 8, 64)     0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 8, 8, 64)     4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 8, 8, 64)     36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 8, 8, 256)    16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 8, 8, 256)    0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 8, 8, 256)    0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 8, 8, 64)     16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 8, 8, 64)     36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 8, 8, 256)    0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 8, 8, 256)    0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 8, 8, 64)     16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 8, 8, 64)     36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 8, 8, 256)    0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 8, 8, 256)    0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 4, 4, 128)    32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 4, 4, 512)    131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 4, 4, 512)    0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 4, 4, 128)    65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 4, 4, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 4, 4, 128)    65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 4, 4, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 4, 4, 128)    65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 4, 4, 128)    147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 4, 4, 512)    0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 4, 4, 512)    0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 2, 2, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 2, 2, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 2, 2, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 2, 2, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 2, 2, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 2, 2, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 2, 2, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 1, 1, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 1, 1, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 1, 1, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 1, 1, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 1, 1, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 1, 1, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 1, 1, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 1, 1, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 1, 1, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 1, 1, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 1, 1, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 1, 1, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# to plot the model
# !pip install netron
import netron
# model_given.save('model_given.h5')
netron.start('model_given.h5',8088)
# Out:
# Requirement already satisfied: netron in c:\users\nithya raj\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (6.9.4)
# Serving 'model_given.h5' at http://localhost:8088
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Nithya Raj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ('localhost', 8088)

# %%
# Function to obtain the output from each layer of the model (To be used for the repeat task type)
output_size = {}
def keras_model_size(model):
    prefix_name = model.name + "_"
    for layer in model.layers:
        if isinstance(layer, (tf.keras.Model,models.Sequential)):
            keras_model_size(layer)
        else:
          out_shape = layer.output_shape
        output_size[prefix_name + layer.name] = out_shape
       
          
    return output_size

# %%
keras_model_size(model_given)
# Out:
# {'resnet50_input_1': [(None, 32, 32, 3)],
#  'resnet50_conv1_pad': (None, 38, 38, 3),
#  'resnet50_conv1_conv': (None, 16, 16, 64),
#  'resnet50_conv1_bn': (None, 16, 16, 64),
#  'resnet50_conv1_relu': (None, 16, 16, 64),
#  'resnet50_pool1_pad': (None, 18, 18, 64),
#  'resnet50_pool1_pool': (None, 8, 8, 64),
#  'resnet50_conv2_block1_1_conv': (None, 8, 8, 64),
#  'resnet50_conv2_block1_1_bn': (None, 8, 8, 64),
#  'resnet50_conv2_block1_1_relu': (None, 8, 8, 64),
#  'resnet50_conv2_block1_2_conv': (None, 8, 8, 64),
#  'resnet50_conv2_block1_2_bn': (None, 8, 8, 64),
#  'resnet50_conv2_block1_2_relu': (None, 8, 8, 64),
#  'resnet50_conv2_block1_0_conv': (None, 8, 8, 256),
#  'resnet50_conv2_block1_3_conv': (None, 8, 8, 256),
#  'resnet50_conv2_block1_0_bn': (None, 8, 8, 256),
#  'resnet50_conv2_block1_3_bn': (None, 8, 8, 256),
#  'resnet50_conv2_block1_add': (None, 8, 8, 256),
#  'resnet50_conv2_block1_out': (None, 8, 8, 256),
#  'resnet50_conv2_block2_1_conv': (None, 8, 8, 64),
#  'resnet50_conv2_block2_1_bn': (None, 8, 8, 64),
#  'resnet50_conv2_block2_1_relu': (None, 8, 8, 64),
#  'resnet50_conv2_block2_2_conv': (None, 8, 8, 64),
#  'resnet50_conv2_block2_2_bn': (None, 8, 8, 64),
#  'resnet50_conv2_block2_2_relu': (None, 8, 8, 64),
#  'resnet50_conv2_block2_3_conv': (None, 8, 8, 256),
#  'resnet50_conv2_block2_3_bn': (None, 8, 8, 256),
#  'resnet50_conv2_block2_add': (None, 8, 8, 256),
#  'resnet50_conv2_block2_out': (None, 8, 8, 256),
#  'resnet50_conv2_block3_1_conv': (None, 8, 8, 64),
#  'resnet50_conv2_block3_1_bn': (None, 8, 8, 64),
#  'resnet50_conv2_block3_1_relu': (None, 8, 8, 64),
#  'resnet50_conv2_block3_2_conv': (None, 8, 8, 64),
#  'resnet50_conv2_block3_2_bn': (None, 8, 8, 64),
#  'resnet50_conv2_block3_2_relu': (None, 8, 8, 64),
#  'resnet50_conv2_block3_3_conv': (None, 8, 8, 256),
#  'resnet50_conv2_block3_3_bn': (None, 8, 8, 256),
#  'resnet50_conv2_block3_add': (None, 8, 8, 256),
#  'resnet50_conv2_block3_out': (None, 8, 8, 256),
#  'resnet50_conv3_block1_1_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block1_1_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block1_1_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block1_2_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block1_2_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block1_2_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block1_0_conv': (None, 4, 4, 512),
#  'resnet50_conv3_block1_3_conv': (None, 4, 4, 512),
#  'resnet50_conv3_block1_0_bn': (None, 4, 4, 512),
#  'resnet50_conv3_block1_3_bn': (None, 4, 4, 512),
#  'resnet50_conv3_block1_add': (None, 4, 4, 512),
#  'resnet50_conv3_block1_out': (None, 4, 4, 512),
#  'resnet50_conv3_block2_1_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block2_1_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block2_1_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block2_2_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block2_2_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block2_2_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block2_3_conv': (None, 4, 4, 512),
#  'resnet50_conv3_block2_3_bn': (None, 4, 4, 512),
#  'resnet50_conv3_block2_add': (None, 4, 4, 512),
#  'resnet50_conv3_block2_out': (None, 4, 4, 512),
#  'resnet50_conv3_block3_1_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block3_1_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block3_1_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block3_2_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block3_2_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block3_2_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block3_3_conv': (None, 4, 4, 512),
#  'resnet50_conv3_block3_3_bn': (None, 4, 4, 512),
#  'resnet50_conv3_block3_add': (None, 4, 4, 512),
#  'resnet50_conv3_block3_out': (None, 4, 4, 512),
#  'resnet50_conv3_block4_1_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block4_1_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block4_1_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block4_2_conv': (None, 4, 4, 128),
#  'resnet50_conv3_block4_2_bn': (None, 4, 4, 128),
#  'resnet50_conv3_block4_2_relu': (None, 4, 4, 128),
#  'resnet50_conv3_block4_3_conv': (None, 4, 4, 512),
#  'resnet50_conv3_block4_3_bn': (None, 4, 4, 512),
#  'resnet50_conv3_block4_add': (None, 4, 4, 512),
#  'resnet50_conv3_block4_out': (None, 4, 4, 512),
#  'resnet50_conv4_block1_1_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block1_1_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block1_1_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block1_2_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block1_2_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block1_2_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block1_0_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block1_3_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block1_0_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block1_3_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block1_add': (None, 2, 2, 1024),
#  'resnet50_conv4_block1_out': (None, 2, 2, 1024),
#  'resnet50_conv4_block2_1_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block2_1_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block2_1_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block2_2_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block2_2_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block2_2_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block2_3_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block2_3_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block2_add': (None, 2, 2, 1024),
#  'resnet50_conv4_block2_out': (None, 2, 2, 1024),
#  'resnet50_conv4_block3_1_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block3_1_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block3_1_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block3_2_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block3_2_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block3_2_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block3_3_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block3_3_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block3_add': (None, 2, 2, 1024),
#  'resnet50_conv4_block3_out': (None, 2, 2, 1024),
#  'resnet50_conv4_block4_1_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block4_1_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block4_1_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block4_2_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block4_2_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block4_2_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block4_3_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block4_3_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block4_add': (None, 2, 2, 1024),
#  'resnet50_conv4_block4_out': (None, 2, 2, 1024),
#  'resnet50_conv4_block5_1_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block5_1_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block5_1_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block5_2_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block5_2_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block5_2_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block5_3_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block5_3_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block5_add': (None, 2, 2, 1024),
#  'resnet50_conv4_block5_out': (None, 2, 2, 1024),
#  'resnet50_conv4_block6_1_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block6_1_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block6_1_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block6_2_conv': (None, 2, 2, 256),
#  'resnet50_conv4_block6_2_bn': (None, 2, 2, 256),
#  'resnet50_conv4_block6_2_relu': (None, 2, 2, 256),
#  'resnet50_conv4_block6_3_conv': (None, 2, 2, 1024),
#  'resnet50_conv4_block6_3_bn': (None, 2, 2, 1024),
#  'resnet50_conv4_block6_add': (None, 2, 2, 1024),
#  'resnet50_conv4_block6_out': (None, 2, 2, 1024),
#  'resnet50_conv5_block1_1_conv': (None, 1, 1, 512),
#  'resnet50_conv5_block1_1_bn': (None, 1, 1, 512),
#  'resnet50_conv5_block1_1_relu': (None, 1, 1, 512),
#  'resnet50_conv5_block1_2_conv': (None, 1, 1, 512),
#  'resnet50_conv5_block1_2_bn': (None, 1, 1, 512),
#  'resnet50_conv5_block1_2_relu': (None, 1, 1, 512),
#  'resnet50_conv5_block1_0_conv': (None, 1, 1, 2048),
#  'resnet50_conv5_block1_3_conv': (None, 1, 1, 2048),
#  'resnet50_conv5_block1_0_bn': (None, 1, 1, 2048),
#  'resnet50_conv5_block1_3_bn': (None, 1, 1, 2048),
#  'resnet50_conv5_block1_add': (None, 1, 1, 2048),
#  'resnet50_conv5_block1_out': (None, 1, 1, 2048),
#  'resnet50_conv5_block2_1_conv': (None, 1, 1, 512),
#  'resnet50_conv5_block2_1_bn': (None, 1, 1, 512),
#  'resnet50_conv5_block2_1_relu': (None, 1, 1, 512),
#  'resnet50_conv5_block2_2_conv': (None, 1, 1, 512),
#  'resnet50_conv5_block2_2_bn': (None, 1, 1, 512),
#  'resnet50_conv5_block2_2_relu': (None, 1, 1, 512),
#  'resnet50_conv5_block2_3_conv': (None, 1, 1, 2048),
#  'resnet50_conv5_block2_3_bn': (None, 1, 1, 2048),
#  'resnet50_conv5_block2_add': (None, 1, 1, 2048),
#  'resnet50_conv5_block2_out': (None, 1, 1, 2048),
#  'resnet50_conv5_block3_1_conv': (None, 1, 1, 512),
#  'resnet50_conv5_block3_1_bn': (None, 1, 1, 512),
#  'resnet50_conv5_block3_1_relu': (None, 1, 1, 512),
#  'resnet50_conv5_block3_2_conv': (None, 1, 1, 512),
#  'resnet50_conv5_block3_2_bn': (None, 1, 1, 512),
#  'resnet50_conv5_block3_2_relu': (None, 1, 1, 512),
#  'resnet50_conv5_block3_3_conv': (None, 1, 1, 2048),
#  'resnet50_conv5_block3_3_bn': (None, 1, 1, 2048),
#  'resnet50_conv5_block3_add': (None, 1, 1, 2048),
#  'resnet50_conv5_block3_out': (None, 1, 1, 2048)}

# %%
# Obtains the output in bits, the memory requirements of each layer

def keras_model_output(model):
    output_dict = {}
    default_dtype = tf.keras.backend.floatx()
    prefix_name = model.name + "_"
    for layer in model.layers:
        if isinstance(layer, (tf.keras.Model,models.Sequential)):
            keras_model_output(layer)
        else:
            no_of_neurons = tf.as_dtype(layer.dtype or default_dtype).size # dtype is float 32 and the size here is 4 bytes(32 bits)
            out_shape = layer.output_shape
            if isinstance(out_shape, list):
                for s in out_shape[0]:
                    if s is None:
                        continue
                    no_of_neurons *= s # Output obtained here is in 4 Bytes 
            else:
                for s in out_shape:
                    if s is None:
                        continue
                    no_of_neurons *= s # Output obtained here is in 4 Bytes 
            no_of_neurons *= 8 # Output obtained in bits
        output_dict[prefix_name + layer.name] = no_of_neurons
       
          
    return output_dict

# %%
keras_model_output(model_given)
# Out:
# {'resnet50_input_1': 98304,
#  'resnet50_conv1_pad': 138624,
#  'resnet50_conv1_conv': 524288,
#  'resnet50_conv1_bn': 524288,
#  'resnet50_conv1_relu': 524288,
#  'resnet50_pool1_pad': 663552,
#  'resnet50_pool1_pool': 131072,
#  'resnet50_conv2_block1_1_conv': 131072,
#  'resnet50_conv2_block1_1_bn': 131072,
#  'resnet50_conv2_block1_1_relu': 131072,
#  'resnet50_conv2_block1_2_conv': 131072,
#  'resnet50_conv2_block1_2_bn': 131072,
#  'resnet50_conv2_block1_2_relu': 131072,
#  'resnet50_conv2_block1_0_conv': 524288,
#  'resnet50_conv2_block1_3_conv': 524288,
#  'resnet50_conv2_block1_0_bn': 524288,
#  'resnet50_conv2_block1_3_bn': 524288,
#  'resnet50_conv2_block1_add': 524288,
#  'resnet50_conv2_block1_out': 524288,
#  'resnet50_conv2_block2_1_conv': 131072,
#  'resnet50_conv2_block2_1_bn': 131072,
#  'resnet50_conv2_block2_1_relu': 131072,
#  'resnet50_conv2_block2_2_conv': 131072,
#  'resnet50_conv2_block2_2_bn': 131072,
#  'resnet50_conv2_block2_2_relu': 131072,
#  'resnet50_conv2_block2_3_conv': 524288,
#  'resnet50_conv2_block2_3_bn': 524288,
#  'resnet50_conv2_block2_add': 524288,
#  'resnet50_conv2_block2_out': 524288,
#  'resnet50_conv2_block3_1_conv': 131072,
#  'resnet50_conv2_block3_1_bn': 131072,
#  'resnet50_conv2_block3_1_relu': 131072,
#  'resnet50_conv2_block3_2_conv': 131072,
#  'resnet50_conv2_block3_2_bn': 131072,
#  'resnet50_conv2_block3_2_relu': 131072,
#  'resnet50_conv2_block3_3_conv': 524288,
#  'resnet50_conv2_block3_3_bn': 524288,
#  'resnet50_conv2_block3_add': 524288,
#  'resnet50_conv2_block3_out': 524288,
#  'resnet50_conv3_block1_1_conv': 65536,
#  'resnet50_conv3_block1_1_bn': 65536,
#  'resnet50_conv3_block1_1_relu': 65536,
#  'resnet50_conv3_block1_2_conv': 65536,
#  'resnet50_conv3_block1_2_bn': 65536,
#  'resnet50_conv3_block1_2_relu': 65536,
#  'resnet50_conv3_block1_0_conv': 262144,
#  'resnet50_conv3_block1_3_conv': 262144,
#  'resnet50_conv3_block1_0_bn': 262144,
#  'resnet50_conv3_block1_3_bn': 262144,
#  'resnet50_conv3_block1_add': 262144,
#  'resnet50_conv3_block1_out': 262144,
#  'resnet50_conv3_block2_1_conv': 65536,
#  'resnet50_conv3_block2_1_bn': 65536,
#  'resnet50_conv3_block2_1_relu': 65536,
#  'resnet50_conv3_block2_2_conv': 65536,
#  'resnet50_conv3_block2_2_bn': 65536,
#  'resnet50_conv3_block2_2_relu': 65536,
#  'resnet50_conv3_block2_3_conv': 262144,
#  'resnet50_conv3_block2_3_bn': 262144,
#  'resnet50_conv3_block2_add': 262144,
#  'resnet50_conv3_block2_out': 262144,
#  'resnet50_conv3_block3_1_conv': 65536,
#  'resnet50_conv3_block3_1_bn': 65536,
#  'resnet50_conv3_block3_1_relu': 65536,
#  'resnet50_conv3_block3_2_conv': 65536,
#  'resnet50_conv3_block3_2_bn': 65536,
#  'resnet50_conv3_block3_2_relu': 65536,
#  'resnet50_conv3_block3_3_conv': 262144,
#  'resnet50_conv3_block3_3_bn': 262144,
#  'resnet50_conv3_block3_add': 262144,
#  'resnet50_conv3_block3_out': 262144,
#  'resnet50_conv3_block4_1_conv': 65536,
#  'resnet50_conv3_block4_1_bn': 65536,
#  'resnet50_conv3_block4_1_relu': 65536,
#  'resnet50_conv3_block4_2_conv': 65536,
#  'resnet50_conv3_block4_2_bn': 65536,
#  'resnet50_conv3_block4_2_relu': 65536,
#  'resnet50_conv3_block4_3_conv': 262144,
#  'resnet50_conv3_block4_3_bn': 262144,
#  'resnet50_conv3_block4_add': 262144,
#  'resnet50_conv3_block4_out': 262144,
#  'resnet50_conv4_block1_1_conv': 32768,
#  'resnet50_conv4_block1_1_bn': 32768,
#  'resnet50_conv4_block1_1_relu': 32768,
#  'resnet50_conv4_block1_2_conv': 32768,
#  'resnet50_conv4_block1_2_bn': 32768,
#  'resnet50_conv4_block1_2_relu': 32768,
#  'resnet50_conv4_block1_0_conv': 131072,
#  'resnet50_conv4_block1_3_conv': 131072,
#  'resnet50_conv4_block1_0_bn': 131072,
#  'resnet50_conv4_block1_3_bn': 131072,
#  'resnet50_conv4_block1_add': 131072,
#  'resnet50_conv4_block1_out': 131072,
#  'resnet50_conv4_block2_1_conv': 32768,
#  'resnet50_conv4_block2_1_bn': 32768,
#  'resnet50_conv4_block2_1_relu': 32768,
#  'resnet50_conv4_block2_2_conv': 32768,
#  'resnet50_conv4_block2_2_bn': 32768,
#  'resnet50_conv4_block2_2_relu': 32768,
#  'resnet50_conv4_block2_3_conv': 131072,
#  'resnet50_conv4_block2_3_bn': 131072,
#  'resnet50_conv4_block2_add': 131072,
#  'resnet50_conv4_block2_out': 131072,
#  'resnet50_conv4_block3_1_conv': 32768,
#  'resnet50_conv4_block3_1_bn': 32768,
#  'resnet50_conv4_block3_1_relu': 32768,
#  'resnet50_conv4_block3_2_conv': 32768,
#  'resnet50_conv4_block3_2_bn': 32768,
#  'resnet50_conv4_block3_2_relu': 32768,
#  'resnet50_conv4_block3_3_conv': 131072,
#  'resnet50_conv4_block3_3_bn': 131072,
#  'resnet50_conv4_block3_add': 131072,
#  'resnet50_conv4_block3_out': 131072,
#  'resnet50_conv4_block4_1_conv': 32768,
#  'resnet50_conv4_block4_1_bn': 32768,
#  'resnet50_conv4_block4_1_relu': 32768,
#  'resnet50_conv4_block4_2_conv': 32768,
#  'resnet50_conv4_block4_2_bn': 32768,
#  'resnet50_conv4_block4_2_relu': 32768,
#  'resnet50_conv4_block4_3_conv': 131072,
#  'resnet50_conv4_block4_3_bn': 131072,
#  'resnet50_conv4_block4_add': 131072,
#  'resnet50_conv4_block4_out': 131072,
#  'resnet50_conv4_block5_1_conv': 32768,
#  'resnet50_conv4_block5_1_bn': 32768,
#  'resnet50_conv4_block5_1_relu': 32768,
#  'resnet50_conv4_block5_2_conv': 32768,
#  'resnet50_conv4_block5_2_bn': 32768,
#  'resnet50_conv4_block5_2_relu': 32768,
#  'resnet50_conv4_block5_3_conv': 131072,
#  'resnet50_conv4_block5_3_bn': 131072,
#  'resnet50_conv4_block5_add': 131072,
#  'resnet50_conv4_block5_out': 131072,
#  'resnet50_conv4_block6_1_conv': 32768,
#  'resnet50_conv4_block6_1_bn': 32768,
#  'resnet50_conv4_block6_1_relu': 32768,
#  'resnet50_conv4_block6_2_conv': 32768,
#  'resnet50_conv4_block6_2_bn': 32768,
#  'resnet50_conv4_block6_2_relu': 32768,
#  'resnet50_conv4_block6_3_conv': 131072,
#  'resnet50_conv4_block6_3_bn': 131072,
#  'resnet50_conv4_block6_add': 131072,
#  'resnet50_conv4_block6_out': 131072,
#  'resnet50_conv5_block1_1_conv': 16384,
#  'resnet50_conv5_block1_1_bn': 16384,
#  'resnet50_conv5_block1_1_relu': 16384,
#  'resnet50_conv5_block1_2_conv': 16384,
#  'resnet50_conv5_block1_2_bn': 16384,
#  'resnet50_conv5_block1_2_relu': 16384,
#  'resnet50_conv5_block1_0_conv': 65536,
#  'resnet50_conv5_block1_3_conv': 65536,
#  'resnet50_conv5_block1_0_bn': 65536,
#  'resnet50_conv5_block1_3_bn': 65536,
#  'resnet50_conv5_block1_add': 65536,
#  'resnet50_conv5_block1_out': 65536,
#  'resnet50_conv5_block2_1_conv': 16384,
#  'resnet50_conv5_block2_1_bn': 16384,
#  'resnet50_conv5_block2_1_relu': 16384,
#  'resnet50_conv5_block2_2_conv': 16384,
#  'resnet50_conv5_block2_2_bn': 16384,
#  'resnet50_conv5_block2_2_relu': 16384,
#  'resnet50_conv5_block2_3_conv': 65536,
#  'resnet50_conv5_block2_3_bn': 65536,
#  'resnet50_conv5_block2_add': 65536,
#  'resnet50_conv5_block2_out': 65536,
#  'resnet50_conv5_block3_1_conv': 16384,
#  'resnet50_conv5_block3_1_bn': 16384,
#  'resnet50_conv5_block3_1_relu': 16384,
#  'resnet50_conv5_block3_2_conv': 16384,
#  'resnet50_conv5_block3_2_bn': 16384,
#  'resnet50_conv5_block3_2_relu': 16384,
#  'resnet50_conv5_block3_3_conv': 65536,
#  'resnet50_conv5_block3_3_bn': 65536,
#  'resnet50_conv5_block3_add': 65536,
#  'resnet50_conv5_block3_out': 65536}

# %%
# EFFECTIVE DATA COMMUNICATION PROBABILITY

# Function to print the effective data communicated 
def data_summary(model,x_test,y_test):

  # Creating dictionary for storing the percent of data communicated eliminating the sparse data
  effective_probability = {}
  
  # Function to add communicated data to the metrics
  def add_metrics(m2):
    "Annotates recursiverly a (non-compiled) model with metrics that calculate probability of non-zero activity"
    prefix_name = m2.name + "_"

    for ll in m2.layers:
        if is_hier_layer(ll):
            add_metrics(ll)
        else:
            my_metric = tf.reduce_sum( tf.math.count_nonzero(ll.output, dtype=tf.int32) / tf.size( ll.output)  )
            name=prefix_name + ll.name
            m2.add_metric(my_metric, name=name)
        
    return

  # Function to check if a layer is model or not
  def is_hier_layer(layer):
      "Finds if layer is actually a model instead of a single layer"
      return type(layer) in [models.Sequential, keras.Model]

  # Clone the model. Note that it is not compiled!
  m2 = keras.models.clone_model(model)
  add_metrics(m2)
  
  # Compiling the cloned model and take the inference
  m2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

  m2.evaluate(x_test[0:100], y_test[0:100]) 
  
  # print('%40s | %20s' % ('Metrics and Layer Name', 'Effective data communicated'))
  # print("*" * 150)
  for l in m2.metrics:
    # print('%40s | %5.4f' % (l.name, l.result().numpy()))
    if l.name!="loss" and l.name!="accuracy" :
      effective_probability[l.name] = l.result().numpy()      

  return effective_probability

# %%
data_summary(model_given, x_train, y_train)
# Out:
# 4/4 [==============================] - 14s 109ms/step - loss: 10.1292 - accuracy: 0.0000e+00 - resnet50_input_1: 0.9591 - resnet50_conv1_pad: 0.6801 - resnet50_conv1_conv: 0.9900 - resnet50_conv1_bn: 0.9900 - resnet50_conv1_relu: 0.4800 - resnet50_pool1_pad: 0.3792 - resnet50_pool1_pool: 0.6477 - resnet50_conv2_block1_1_conv: 0.9980 - resnet50_conv2_block1_1_bn: 0.9980 - resnet50_conv2_block1_1_relu: 0.4412 - resnet50_conv2_block1_2_conv: 1.0000 - resnet50_conv2_block1_2_bn: 1.0000 - resnet50_conv2_block1_2_relu: 0.4906 - resnet50_conv2_block1_0_conv: 0.9980 - resnet50_conv2_block1_3_conv: 1.0000 - resnet50_conv2_block1_0_bn: 0.9980 - resnet50_conv2_block1_3_bn: 1.0000 - resnet50_conv2_block1_add: 1.0000 - resnet50_conv2_block1_out: 0.4507 - resnet50_conv2_block2_1_conv: 1.0000 - resnet50_conv2_block2_1_bn: 1.0000 - resnet50_conv2_block2_1_relu: 0.4670 - resnet50_conv2_block2_2_conv: 1.0000 - resnet50_conv2_block2_2_bn: 1.0000 - resnet50_conv2_block2_2_relu: 0.4846 - resnet50_conv2_block2_3_conv: 1.0000 - resnet50_conv2_block2_3_bn: 1.0000 - resnet50_conv2_block2_add: 1.0000 - resnet50_conv2_block2_out: 0.6831 - resnet50_conv2_block3_1_conv: 1.0000 - resnet50_conv2_block3_1_bn: 1.0000 - resnet50_conv2_block3_1_relu: 0.4074 - resnet50_conv2_block3_2_conv: 1.0000 - resnet50_conv2_block3_2_bn: 1.0000 - resnet50_conv2_block3_2_relu: 0.5322 - resnet50_conv2_block3_3_conv: 1.0000 - resnet50_conv2_block3_3_bn: 1.0000 - resnet50_conv2_block3_add: 1.0000 - resnet50_conv2_block3_out: 0.7572 - resnet50_conv3_block1_1_conv: 1.0000 - resnet50_conv3_block1_1_bn: 1.0000 - resnet50_conv3_block1_1_relu: 0.5217 - resnet50_conv3_block1_2_conv: 1.0000 - resnet50_conv3_block1_2_bn: 1.0000 - resnet50_conv3_block1_2_relu: 0.4932 - resnet50_conv3_block1_0_conv: 1.0000 - resnet50_conv3_block1_3_conv: 1.0000 - resnet50_conv3_block1_0_bn: 1.0000 - resnet50_conv3_block1_3_bn: 1.0000 - resnet50_conv3_block1_add: 1.0000 - resnet50_conv3_block1_out: 0.4987 - resnet50_conv3_block2_1_conv: 1.0000 - resnet50_conv3_block2_1_bn: 1.0000 - resnet50_conv3_block2_1_relu: 0.5863 - resnet50_conv3_block2_2_conv: 1.0000 - resnet50_conv3_block2_2_bn: 1.0000 - resnet50_conv3_block2_2_relu: 0.4501 - resnet50_conv3_block2_3_conv: 1.0000 - resnet50_conv3_block2_3_bn: 1.0000 - resnet50_conv3_block2_add: 1.0000 - resnet50_conv3_block2_out: 0.7167 - resnet50_conv3_block3_1_conv: 1.0000 - resnet50_conv3_block3_1_bn: 1.0000 - resnet50_conv3_block3_1_relu: 0.5086 - resnet50_conv3_block3_2_conv: 1.0000 - resnet50_conv3_block3_2_bn: 1.0000 - resnet50_conv3_block3_2_relu: 0.5111 - resnet50_conv3_block3_3_conv: 1.0000 - resnet50_conv3_block3_3_bn: 1.0000 - resnet50_conv3_block3_add: 1.0000 - resnet50_conv3_block3_out: 0.7567 - resnet50_conv3_block4_1_conv: 1.0000 - resnet50_conv3_block4_1_bn: 1.0000 - resnet50_conv3_block4_1_relu: 0.5192 - resnet50_conv3_block4_2_conv: 1.0000 - resnet50_conv3_block4_2_bn: 1.0000 - resnet50_conv3_block4_2_relu: 0.4693 - resnet50_conv3_block4_3_conv: 1.0000 - resnet50_conv3_block4_3_bn: 1.0000 - resnet50_conv3_block4_add: 1.0000 - resnet50_conv3_block4_out: 0.7805 - resnet50_conv4_block1_1_conv: 1.0000 - resnet50_conv4_block1_1_bn: 1.0000 - resnet50_conv4_block1_1_relu: 0.4917 - resnet50_conv4_block1_2_conv: 1.0000 - resnet50_conv4_block1_2_bn: 1.0000 - resnet50_conv4_block1_2_relu: 0.4683 - resnet50_conv4_block1_0_conv: 1.0000 - resnet50_conv4_block1_3_conv: 1.0000 - resnet50_conv4_block1_0_bn: 1.0000 - resnet50_conv4_block1_3_bn: 1.0000 - resnet50_conv4_block1_add: 1.0000 - resnet50_conv4_block1_out: 0.5005 - resnet50_conv4_block2_1_conv: 1.0000 - resnet50_conv4_block2_1_bn: 1.0000 - resnet50_conv4_block2_1_relu: 0.4520 - resnet50_conv4_block2_2_conv: 1.0000 - resnet50_conv4_block2_2_bn: 1.0000 - resnet50_conv4_block2_2_relu: 0.5123 - resnet50_conv4_block2_3_conv: 1.0000 - resnet50_conv4_block2_3_bn: 1.0000 - resnet50_conv4_block2_add: 1.0000 - resnet50_conv4_block2_out: 0.7161 - resnet50_conv4_block3_1_conv: 1.0000 - resnet50_conv4_block3_1_bn: 1.000 ...
# {'resnet50_input_1': 0.9591013590494791,
#  'resnet50_conv1_pad': 0.6801383598799631,
#  'resnet50_conv1_conv': 0.989959716796875,
#  'resnet50_conv1_bn': 0.989959716796875,
#  'resnet50_conv1_relu': 0.47998666763305664,
#  'resnet50_pool1_pad': 0.3792487250434028,
#  'resnet50_pool1_pool': 0.6476974487304688,
#  'resnet50_conv2_block1_1_conv': 0.998046875,
#  'resnet50_conv2_block1_1_bn': 0.998046875,
#  'resnet50_conv2_block1_1_relu': 0.4412345886230469,
#  'resnet50_conv2_block1_2_conv': 1.0,
#  'resnet50_conv2_block1_2_bn': 1.0,
#  'resnet50_conv2_block1_2_relu': 0.4906120300292969,
#  'resnet50_conv2_block1_0_conv': 0.998046875,
#  'resnet50_conv2_block1_3_conv': 1.0,
#  'resnet50_conv2_block1_0_bn': 0.998046875,
#  'resnet50_conv2_block1_3_bn': 1.0,
#  'resnet50_conv2_block1_add': 1.0,
#  'resnet50_conv2_block1_out': 0.4506549835205078,
#  'resnet50_conv2_block2_1_conv': 1.0,
#  'resnet50_conv2_block2_1_bn': 1.0,
#  'resnet50_conv2_block2_1_relu': 0.4670085906982422,
#  'resnet50_conv2_block2_2_conv': 1.0,
#  'resnet50_conv2_block2_2_bn': 1.0,
#  'resnet50_conv2_block2_2_relu': 0.484619140625,
#  'resnet50_conv2_block2_3_conv': 1.0,
#  'resnet50_conv2_block2_3_bn': 1.0,
#  'resnet50_conv2_block2_add': 1.0,
#  'resnet50_conv2_block2_out': 0.6830763816833496,
#  'resnet50_conv2_block3_1_conv': 1.0,
#  'resnet50_conv2_block3_1_bn': 1.0,
#  'resnet50_conv2_block3_1_relu': 0.4073619842529297,
#  'resnet50_conv2_block3_2_conv': 1.0,
#  'resnet50_conv2_block3_2_bn': 1.0,
#  'resnet50_conv2_block3_2_relu': 0.5322360992431641,
#  'resnet50_conv2_block3_3_conv': 1.0,
#  'resnet50_conv2_block3_3_bn': 1.0,
#  'resnet50_conv2_block3_add': 1.0,
#  'resnet50_conv2_block3_out': 0.7571597099304199,
#  'resnet50_conv3_block1_1_conv': 1.0,
#  'resnet50_conv3_block1_1_bn': 1.0,
#  'resnet50_conv3_block1_1_relu': 0.5217094421386719,
#  'resnet50_conv3_block1_2_conv': 1.0,
#  'resnet50_conv3_block1_2_bn': 1.0,
#  'resnet50_conv3_block1_2_relu': 0.49321746826171875,
#  'resnet50_conv3_block1_0_conv': 1.0,
#  'resnet50_conv3_block1_3_conv': 1.0,
#  'resnet50_conv3_block1_0_bn': 1.0,
#  'resnet50_conv3_block1_3_bn': 1.0,
#  'resnet50_conv3_block1_add': 1.0,
#  'resnet50_conv3_block1_out': 0.4987144470214844,
#  'resnet50_conv3_block2_1_conv': 1.0,
#  'resnet50_conv3_block2_1_bn': 1.0,
#  'resnet50_conv3_block2_1_relu': 0.586273193359375,
#  'resnet50_conv3_block2_2_conv': 1.0,
#  'resnet50_conv3_block2_2_bn': 1.0,
#  'resnet50_conv3_block2_2_relu': 0.450103759765625,
#  'resnet50_conv3_block2_3_conv': 1.0,
#  'resnet50_conv3_block2_3_bn': 1.0,
#  'resnet50_conv3_block2_add': 1.0,
#  'resnet50_conv3_block2_out': 0.7167205810546875,
#  'resnet50_conv3_block3_1_conv': 1.0,
#  'resnet50_conv3_block3_1_bn': 1.0,
#  'resnet50_conv3_block3_1_relu': 0.5085639953613281,
#  'resnet50_conv3_block3_2_conv': 1.0,
#  'resnet50_conv3_block3_2_bn': 1.0,
#  'resnet50_conv3_block3_2_relu': 0.5110855102539062,
#  'resnet50_conv3_block3_3_conv': 1.0,
#  'resnet50_conv3_block3_3_bn': 1.0,
#  'resnet50_conv3_block3_add': 1.0,
#  'resnet50_conv3_block3_out': 0.7567033767700195,
#  'resnet50_conv3_block4_1_conv': 1.0,
#  'resnet50_conv3_block4_1_bn': 1.0,
#  'resnet50_conv3_block4_1_relu': 0.5191879272460938,
#  'resnet50_conv3_block4_2_conv': 1.0,
#  'resnet50_conv3_block4_2_bn': 1.0,
#  'resnet50_conv3_block4_2_relu': 0.46930694580078125,
#  'resnet50_conv3_block4_3_conv': 1.0,
#  'resnet50_conv3_block4_3_bn': 1.0,
#  'resnet50_conv3_block4_add': 1.0,
#  'resnet50_conv3_block4_out': 0.7805118560791016,
#  'resnet50_conv4_block1_1_conv': 1.0,
#  'resnet50_conv4_block1_1_bn': 1.0,
#  'resnet50_conv4_block1_1_relu': 0.49166107177734375,
#  'resnet50_conv4_block1_2_conv': 1.0,
#  'resnet50_conv4_block1_2_bn': 1.0,
#  'resnet50_conv4_block1_2_relu': 0.46829986572265625,
#  'resnet50_conv4_block1_0_conv': 1.0,
#  'resnet50_conv4_block1_3_conv': 1.0,
#  'resnet50_conv4_block1_0_bn': 1.0,
#  'resnet50_conv4_block1_3_bn': 1.0,
#  'resnet50_conv4_block1_add': 1.0,
#  'resnet50_conv4_block1_out': 0.5004501342773438,
#  'resnet50_conv4_block2_1_conv': 1.0,
#  'resnet50_conv4_block2_1_bn': 1.0,
#  'resnet50_conv4_block2_1_relu': 0.45200347900390625,
#  'resnet50_conv4_block2_2_conv': 1.0,
#  'resnet50_conv4_block2_2_bn': 1.0,
#  'resnet50_conv4_block2_2_relu': 0.5123291015625,
#  'resnet50_conv4_block2_3_conv': 1.0,
#  'resnet50_conv4_block2_3_bn': 1.0,
#  'resnet50_conv4_block2_add': 1.0,
#  'resnet50_conv4_block2_out': 0.7160873413085938,
#  'resnet50_conv4_block3_1_conv': 1.0,
#  'resnet50_conv4_block3_1_bn': 1.0,
#  'resnet50_conv4_block3_1_relu': 0.5133743286132812,
#  'resnet50_conv4_block3_2_conv': 1.0,
#  'resnet50_conv4_block3_2_bn': 1.0,
#  'resnet50_conv4_block3_2_relu': 0.48553466796875,
#  'resnet50_conv4_block3_3_conv': 1.0,
#  'resnet50_conv4_block3_3_bn': 1.0,
#  'resnet50_conv4_block3_add': 1.0,
#  'resnet50_conv4_block3_out': 0.7641544342041016,
#  'resnet50_conv4_block4_1_conv': 1.0,
#  'resnet50_conv4_block4_1_bn': 1.0,
#  'resnet50_conv4_block4_1_relu': 0.5197677612304688,
#  'resnet50_conv4_block4_2_conv': 1.0,
#  'resnet50_conv4_block4_2_bn': 1.0,
#  'resnet50_conv4_block4_2_relu': 0.47796630859375,
#  'resnet50_conv4_block4_3_conv': 1.0,
#  'resnet50_conv4_block4_3_bn': 1.0,
#  'resnet50_conv4_block4_add': 1.0,
#  'resnet50_conv4_block4_out': 0.8026199340820312,
#  'resnet50_conv4_block5_1_conv': 1.0,
#  'resnet50_conv4_block5_1_bn': 1.0,
#  'resnet50_conv4_block5_1_relu': 0.5138778686523438,
#  'resnet50_conv4_block5_2_conv': 1.0,
#  'resnet50_conv4_block5_2_bn': 1.0,
#  'resnet50_conv4_block5_2_relu': 0.5055160522460938,
#  'resnet50_conv4_block5_3_conv': 1.0,
#  'resnet50_conv4_block5_3_bn': 1.0,
#  'resnet50_conv4_block5_add': 1.0,
#  'resnet50_conv4_block5_out': 0.8155918121337891,
#  'resnet50_conv4_block6_1_conv': 1.0,
#  'resnet50_conv4_block6_1_bn': 1.0,
#  'resnet50_conv4_block6_1_relu': 0.48635101318359375,
#  'resnet50_conv4_block6_2_conv': 1.0,
#  'resnet50_conv4_block6_2_bn': 1.0,
#  'resnet50_conv4_block6_2_relu': 0.49346160888671875,
#  'resnet50_conv4_block6_3_conv': 1.0,
#  'resnet50_conv4_block6_3_bn': 1.0,
#  'resnet50_conv4_block6_add': 1.0,
#  'resnet50_conv4_block6_out': 0.8314323425292969,
#  'resnet50_conv5_block1_1_conv': 1.0,
#  'resnet50_conv5_block1_1_bn': 1.0,
#  'resnet50_conv5_block1_1_relu': 0.5236053466796875,
#  'resnet50_conv5_block1_2_conv': 1.0,
#  'resnet50_conv5_block1_2_bn': 1.0,
#  'resnet50_conv5_block1_2_relu': 0.4785919189453125,
#  'resnet50_conv5_block1_0_conv': 1.0,
#  'resnet50_conv5_block1_3_conv': 1.0,
#  'resnet50_conv5_block1_0_bn': 1.0,
#  'resnet50_conv5_block1_3_bn': 1.0,
#  'resnet50_conv5_block1_add': 1.0,
#  'resnet50_conv5_block1_out': 0.48961639404296875,
#  'resnet50_conv5_block2_1_conv': 1.0,
#  'resnet50_conv5_block2_1_bn': 1.0,
#  'resnet50_conv5_block2_1_relu': 0.5046539306640625,
#  'resnet50_conv5_block2_2_conv': 1.0,
#  'resnet50_conv5_block2_2_bn': 1.0,
#  'resnet50_conv5_block2_2_relu': 0.5390472412109375,
#  'resnet50_conv5_block2_3_conv': 1.0,
#  'resnet50_conv5_block2_3_bn': 1.0,
#  'resnet50_conv5_block2_add': 1.0,
#  'resnet50_conv5_block2_out': 0.7289848327636719,
#  'resnet50_conv5_block3_1_conv': 1.0,
#  'resnet50_conv5_block3_1_bn': 1.0,
#  'resnet50_conv5_block3_1_relu': 0.5296173095703125,
#  'resnet50_conv5_block3_2_conv': 1.0,
#  'resnet50_conv5_block3_2_bn': 1.0,
#  'resnet50_conv5_block3_2_relu': 0.5049896240234375,
#  'resnet50_conv5_block3_3_conv': 1.0,
#  'resnet50_conv5_block3_3_bn': 1.0,
#  'resnet50_conv5_block3_add': 1.0,
#  'resnet50_conv5_block3_out': 0.7854843139648438}

# %%
# to count the number of tasks required:

def layer_count(model):
    count = 0
    for l in model.layers:
        if isinstance(l, (tf.keras.Model,models.Sequential)):
            for ll in l.layers:
                count = count + 1
        else:
            count = count + 1
    return (f'tasks_number = {count+1}')

# %%
layer_count(model_given)
# Out:
# 'tasks_number = 176'
